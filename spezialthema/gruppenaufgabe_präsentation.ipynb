# %% [markdown]
# # Gruppenaufgabe: Normalisierung

# %% [markdown]
# ### Inhalt

# %% [markdown]
# * Wiederholung: Definition funktionaler Abhängigkeiten
# * Programm zur Identifikation einer funktionalen Abhängigkeit in einer Tabelle
# * Erweiterung des Programms um unscharfe und zusammengesetzte funktionale Abhängigkeiten
# * Überblick über Algorithmen zur Erkennung funktionaler Abhängigkeiten
# * Anwendung auf Datensätze

# %% [markdown]
# ### Vorbereitung

# %%
import pandas as pd
import psycopg2
import yaml
from itertools import combinations

# %% [markdown]
# Verbindung zur Datenbank herstellen:

# %%
with open('config.yaml') as f:
    config = yaml.safe_load(f)
conn = psycopg2.connect(database = config['gruppenaufgabe']['db'], 
                        user = config['gruppenaufgabe']['user'], 
                        password = config['gruppenaufgabe']['pass'])
cur = conn.cursor()

# %% [markdown]
# Nützliche Funktionen:

# %%
def sql(sql: str):
    return pd.read_sql(sql, conn)

# %%
def print_full(x):
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 2000)
    pd.set_option('display.float_format', '{:20,.2f}'.format)
    pd.set_option('display.max_colwidth', None)
    print(x)
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')
    pd.reset_option('display.float_format')
    pd.reset_option('display.max_colwidth')

# %% [markdown]
# Tabelle zum Testen erstellen:

# %%
def create():
    with conn:
        with conn.cursor() as cur:
            cur.execute('CREATE TABLE test (A varchar(2), B varchar(2), C varchar(2),D varchar(2))')
            cur.execute('INSERT INTO test(A, B, C, D) values(%s, %s, %s, %s);', ['a1', 'b1', 'c1', 'd2'])
            cur.execute('INSERT INTO test(A, B, C, D) values(%s, %s, %s, %s);', ['a2', 'b2', 'c1', 'd1'])
            cur.execute('INSERT INTO test(A, B, C, D) values(%s, %s, %s, %s);', ['a1', 'b1', 'c2', 'd1'])
            cur.execute('INSERT INTO test(A, B, C, D) values(%s, %s, %s, %s);', ['a3', 'b1', 'c1', 'd1'])

# %%
create()

# %% [markdown]
# ### Aufgabe 1

# %% [markdown]
# Schreiben Sie ein (zunächst einfach gehaltenes) Programm, welches
# (möglichst effizient) auf Basis des Systemkatalogs einer PostgreSQL
# Datenbank funktionale Abhängigkeiten zwischen einzelnen Attributen $(A
# \rightarrow B)$ einer Relation erkennen kann und darauf basierend Vorschläge für
# die Auslagerung von Tabellen macht. Untersuchen Sie die Laufzeiten
# unterschiedlicher Implementierungsvarianten.

# %% [markdown]
# **Was sind funktionale Abhängigkeiten?**

# %% [markdown]
# **Definition:** B ist von A funktional abhängig $(A
# \rightarrow B)$ genau dann, wenn in einer Relation $R$ zu jedem Wert in $A$ genau ein Wert von $B$ existiert.
#
# Formal: $\forall x, y \in R: x.A = y.A \Longrightarrow x.B = y.B$

# %% [markdown]
# **Beispiel:**
# * In der Relation $Student (\underline{MatrNr}, \underline{LVID}, Bezeichnung, Dozent, Note)$ ist die Bezeichnung und der Dozent der Lehrveranstaltung von LVID funktional abhängig, d.h. es gilt $LVID \rightarrow Bezeichnung$ und $LVID \rightarrow Dozent$.

# %% [markdown]
# Beispieltabelle:

# %%
sql('SELECT * FROM test;')
# Out:
#     a   b   c   d
# 0  a1  b1  c1  d2
# 1  a2  b2  c1  d1
# 2  a1  b1  c2  d1
# 3  a3  b1  c1  d1

# %% [markdown]
# * In der Relation $Test (A, B, C, D)$ gilt $A \rightarrow B$.

# %% [markdown]
# **Mögliche SQL-Skripts, die eine funktionale Abhängigkeit identifizieren**

# %% [markdown]
# Überprüfung der funktionalen Abhängigkeit $A \rightarrow B$. Wird eine leere Liste zurückgegeben, ist $B$ von $A$ funktional abhängig.

# %%
cur.execute('SELECT * FROM test t1, test t2 WHERE t1.a = t2.a AND t1.b <> t2.b')
print(cur.fetchall())
# Out:
# []

# %%
cur.execute('SELECT a FROM test GROUP BY a HAVING COUNT(DISTINCT b) > 1;')
print(cur.fetchall())
# Out:
# []

# %% [markdown]
# Welches der beiden SQL-Statements ist effizienter?

# %% [markdown]
# - der `EXPLAIN` Befehl liefert den Ausführungsplan eines SQL-Statements
# - die Ausgabe ist als eine Baumstruktur zu lesen (von unten nach oben)

# %%
print_full(sql('EXPLAIN SELECT * FROM test t1, test t2 WHERE t1.a = t2.a AND t1.b <> t2.b;'))
# Out:
#                                                            QUERY PLAN
# 0                        Hash Join  (cost=1.09..2.23 rows=2 width=24)
# 1                            Hash Cond: ((t1.a)::text = (t2.a)::text)
# 2                         Join Filter: ((t1.b)::text <> (t2.b)::text)
# 3          ->  Seq Scan on test t1  (cost=0.00..1.04 rows=4 width=12)
# 4                         ->  Hash  (cost=1.04..1.04 rows=4 width=12)
# 5          ->  Seq Scan on test t2  (cost=0.00..1.04 rows=4 width=12)

# %% [markdown]
# Ausführungsplan als Baumstruktur:

# %% [markdown]
# Hash Join<br>
# ├── Seq Scan<br>
# └── Hash<br>
# $\;\;\;\;\;\;$└── Seq Scan<br>

# %% [markdown]
# - der zweite Wert bei `cost` schätzt die Dauer für jeden Knoten (in willkürlichen Einheiten)
# - die geschätzten Kosten des gesamten SQL-Statements betragen 2.23

# %%
print_full(sql('EXPLAIN SELECT a FROM test GROUP BY a HAVING COUNT(DISTINCT b) > 1;'))
# Out:
#                                                        QUERY PLAN
# 0                GroupAggregate  (cost=1.08..1.15 rows=1 width=3)
# 1                                                    Group Key: a
# 2                                 Filter: (count(DISTINCT b) > 1)
# 3                      ->  Sort  (cost=1.08..1.09 rows=4 width=6)
# 4                                                     Sort Key: a
# 5          ->  Seq Scan on test  (cost=0.00..1.04 rows=4 width=6)

# %% [markdown]
# - das zweite SQL-Statement ist effizienter (gesamte Kosten bei 1.15)
# - um Laufzeiten (in Sekunden) zu untersuchen kann auch der Befehl `EXPLAIN ANALYZE` verwendet werden

# %% [markdown]
# **Programm zur Identifikation von funktionalen Abhängigkeiten in einer Relation**

# %%
def func_dep(tname: str):
    
    # Speichere Spaltennamen von Tabelle in Liste
    cols_df = sql(f'''SELECT column_name FROM information_schema.columns WHERE table_name = '{tname}';''')
    cols = cols_df['column_name'].values.tolist()
    
    dep = []
    
    with conn:
        with conn.cursor() as cur:
            
            # Iteriere über alle Spaltenpaare
            for i in cols:
                for j in cols:
                    if i==j:
                        continue
                    cur.execute(f'SELECT {i} FROM {tname} GROUP BY {i} HAVING COUNT(DISTINCT {j}) > 1;')
                    res = cur.fetchall()
                    
                    # Falls die zurückgegebene Liste des SQL-Statements leer ist, wurde FA gefunden
                    if not res:
                        dep.append(f'{i} -> {j}')
                        
    return dep
                
func_dep('test')
# Out:
# ['a -> b']

# %% [markdown]
# Komplexitätsklasse: $O(n^2 m^2)$ wobei $n$ die Anzahl der Spalten  und $m$ die Anzahl der Zeilen einer Relation ist

# %% [markdown]
# ### Aufgabe 2

# %% [markdown]
# Versuchen Sie, Ihr Programm um die folgenden Features zu erweitern:
#
# * Berücksichtigung “unscharfer” funktionaler Abhängigkeiten, $(A→ B \text{ zu } 98\%)$
# * Berücksichtigung funktionaler Abhängigkeiten zwischen mehreren Attributen $(A → BC , AB→C, AB→CD)$

# %% [markdown]
# **Berücksichtigung unscharfer Abhängigkeiten**

# %%
def func_dep_unclear(tname: str):
    
    cols_df = sql(f'''SELECT column_name FROM information_schema.columns WHERE table_name = '{tname}';''')
    cols = cols_df['column_name'].values.tolist() 
    
    dep = {}
    
    with conn:
        with conn.cursor() as cur:
            for i in cols:
                for j in cols:
                    if i==j:
                        continue
                    
                    # SQL-Statement
                    cur.execute(f'''SELECT COUNT("{i}"),COUNT(DISTINCT "{j}") FROM {tname} GROUP BY "{i}";''')
                    res = cur.fetchall()
                    
                    # z.B. für A -> C:
                    # A    C
                    # a_1  c_1
                    # a_2  c_1
                    # a_1  c_2
                    # a_3  c_1
                    
                    # res = [(2,2), (1,1), (1,1)]
                    
                    n = 0
                    p = 0
                    
                    # Durchlaufe Tupel der Ergebnisliste
                    for k in range(0,len(res)):
                        
                        # Summiere über den ersten Eintrag im Tupel, d.h. n = Anzahl der Zeilen
                        n = n + res[k][0]
                        
                        # p = Anzahl der Zeilen, bei denen eine FA besteht
                        if res[k][1] == 1:
                            p = p + res[k][0]
                    p = p/n # p = 2, n = 4 
                    
                    # In 50% der Fälle ist C von A funktional abhängig
                    
                    # Speichere FA's in einem dictionary
                    if i not in dep.keys():
                        dep[i] = [(j,p)]
                    else:
                        dep[i].append((j,p))
                    
    return dep
                
func_dep_unclear('test')
# Out:
# {'a': [('b', 1.0), ('c', 0.5), ('d', 0.5)],
#  'b': [('a', 0.25), ('c', 0.25), ('d', 0.25)],
#  'c': [('a', 0.25), ('b', 0.25), ('d', 0.25)],
#  'd': [('a', 0.25), ('b', 0.25), ('c', 0.25)]}

# %% [markdown]
# **Berücksichtigung funktionaler Abhängigkeiten zwischen mehreren Attributen**

# %%
def func_dep_unclear_all(tname: str):
    
    cols_df = sql(f'''SELECT column_name FROM information_schema.columns WHERE table_name = '{tname}';''')
    cols = cols_df['column_name'].values.tolist()
    
    dep = {}
    
    with conn:
        with conn.cursor() as cur:
            count = 0
            for i in range(0,len(cols)):
                for j in range(0,len(cols)):
                    if i==j:
                        continue
                        
                    # Prüfe auf FA der Form A -> B
                    cur.execute(f'''SELECT COUNT("{cols[i]}"),COUNT(DISTINCT "{cols[j]}") FROM {tname} 
                                    GROUP BY "{cols[i]}";''')
                    res = cur.fetchall()
                    
                    # Berechne unscharfe FA
                    n = 0
                    p = 0
                    for k in range(0,len(res)):
                        n = n + res[k][0]
                        if res[k][1] == 1:
                            p = p+ res[k][0]
                    p = p/n
                    
                    # Speichere FA's in einem dictionary
                    if cols[i] not in dep.keys():
                        dep[cols[i]] = [(cols[j],p)]
                    else:
                        dep[cols[i]].append((cols[j],p))
                
                # Vermeide doppelte Prüfung der FA. Z.B. ist AB -> C identisch zu BA -> C,
                # daher startet für i = Spalte B die zweite for-Schleife erst bei j = Spalte B
                for j in range(0 + count,len(cols)):
                    if i==j:
                        continue

                    for k in range(0,len(cols)):
                        if i==k or j==k:
                            continue

                        # Prüfe auf FA der Form AB -> C
                        cur.execute(f'''SELECT "{cols[i]}","{cols[j]}" FROM {tname} GROUP BY "{cols[i]}","{cols[j]}" 
                                        HAVING COUNT(DISTINCT "{cols[k]}") > 1;''')
                        res = cur.fetchall()
                        
                        if not res:                        
                            if f'{cols[i]}, {cols[j]}' not in dep.keys():
                                dep[f'{cols[i]}, {cols[j]}'] = [(cols[k],1)]
                            else:
                                dep[f'{cols[i]}, {cols[j]}'].append((cols[k],1))
                        
                count += 1
                
    return dep

                        
                        
                
dep = func_dep_unclear_all('test')
dep
# Out:
# {'a': [('b', 1.0), ('c', 0.5), ('d', 0.5)],
#  'a, c': [('b', 1), ('d', 1)],
#  'a, d': [('b', 1), ('c', 1)],
#  'b': [('a', 0.25), ('c', 0.25), ('d', 0.25)],
#  'c': [('a', 0.25), ('b', 0.25), ('d', 0.25)],
#  'd': [('a', 0.25), ('b', 0.25), ('c', 0.25)]}

# %%
def parse_dep(dep):
    print('Funktionale Abhängigkeiten:')
    for key, values in dep.items():
        lst = [] 
        
        # FA der Form A -> B und AB -> C parsen
        for value in values:
            print(f'{key} -> {value[0]}: {value[1]}')
            if value[1]==1:
                lst.append(value[0])
        
        # FA der Form A -> BC und AB -> CD parsen
        # Die FA A -> BC ergibt sich aus den FA A -> B und A -> C
        # Die FA AB -> CD ergibt sich aus den FA AB -> C und AB -> D
        if len(lst) > 1:
            combs = combinations(lst, 2)
            for comb in list(combs):
                print(f'{key} -> {comb[0]}, {comb[1]}: 1')

parse_dep(dep)
# Out:
# Funktionale Abhängigkeiten:
# a -> b: 1.0
# a -> c: 0.5
# a -> d: 0.5
# a, c -> b: 1
# a, c -> d: 1
# a, c -> b, d: 1
# a, d -> b: 1
# a, d -> c: 1
# a, d -> b, c: 1
# b -> a: 0.25
# b -> c: 0.25
# b -> d: 0.25
# c -> a: 0.25
# c -> b: 0.25
# c -> d: 0.25
# d -> a: 0.25
# d -> b: 0.25
# d -> c: 0.25

# %% [markdown]
# Weitere Informationen: [Armstrong's axioms](https://en.wikipedia.org/wiki/Armstrong%27s_axioms)

# %% [markdown]
# ### Aufgabe 3

# %% [markdown]
# Sobald Sie bei (2) nicht mehr unmittelbar weiterkommen: recherchieren
# Sie, welche Ansätze für die o.g. Probleme bereits zur Verfügung stehen
# (Paper, Implementierungen) und versuchen Sie zu verstehen, wie diese
# grundsätzlich funktionieren. Vergleichen Sie diese mit Ihrem eigenen
# Ansatz.

# %% [markdown]
# **Vorhandene Implementierung einer Postgresql Datenbank**

# %%
cur.execute('CREATE STATISTICS s1 (dependencies) ON a,b,c,d FROM test') 
cur.execute('ANALYZE test')

# %%
cur.execute('SELECT dependencies FROM pg_stats_ext')
print(cur.fetchall())
# Out:
# [('{"1 => 2": 1.000000, "1 => 3": 0.500000, "1 => 4": 0.500000, "2 => 1": 0.250000, "2 => 3": 0.250000, "2 => 4": 0.250000, "3 => 1": 0.250000, "3 => 2": 0.250000, "3 => 4": 0.250000, "4 => 1": 0.250000, "4 => 2": 0.250000, "4 => 3": 0.250000, "1, 2 => 3": 0.500000, "1, 2 => 4": 0.500000, "1, 3 => 2": 1.000000, "1, 3 => 4": 1.000000, "1, 4 => 2": 1.000000, "1, 4 => 3": 1.000000, "2, 3 => 1": 0.500000, "2, 3 => 4": 0.500000, "2, 4 => 1": 0.500000, "2, 4 => 3": 0.500000, "3, 4 => 1": 0.500000, "3, 4 => 2": 0.500000, "1, 2, 3 => 4": 1.000000, "1, 2, 4 => 3": 1.000000, "1, 3, 4 => 2": 1.000000, "2, 3, 4 => 1": 1.000000}',)]

# %% [markdown]
# ### Aufgabe 4

# %% [markdown]
# Testen Sie Ihren Ansatz:
# * Mit den als “flat table” geladenen NHTSA Complaints
# * Mit einem beliebigen anderen für Sie interessanten Datensatz

# %% [markdown]
# **NHTSA Complaints**

# %%
sql('''SELECT * FROM complaint LIMIT 5;''')
# Out:
#    CMPLID   ODINO                MFR_NAME MAKETXT     MODELTXT  YEARTXT CRASH  \
# 0       1  958241      Volvo Car USA, LLC   VOLVO          760   1987.0     N
# 1       2  958130      Ford Motor Company    FORD  THUNDERBIRD   1992.0     N
# 2       3  958132      Kia Motors America     KIA       SEPHIA   1994.0     Y
# 3       4  958133  Chrysler (FCA US, LLC)   DODGE          600   1987.0     N
# 4       5  958137  Chrysler (FCA US, LLC)   DODGE      CARAVAN   1991.0     N
#
#      FAILDATE FIRE  INJURED  ...  RESTRAINT_TYPE DEALER_NAME DEALER_TEL  \
# 0         NaN    N        0  ...            None        None       None
# 1  19941222.0    N        0  ...            None        None       None
# 2  19941230.0    N        0  ...            None        None       None
# 3  19941231.0    N        0  ...            None        None       None
# 4  19941218.0    N        0  ...            None        None       None
#
#   DEALER_CITY DEALER_STATE  DEALER_ZIP  PROD_TYPE REPAIRED_YN  MEDICAL_ATTN  \
# 0        None         None        None          V           N             N
# 1        None         None        None          V           N             N
# 2        None         None        None          V           N             N
# 3        None         None        None          V           N             N
# 4        None         None        None          V           N             N
#
#   VEHICLES_TOWED_
# 0               N
# 1               N
# 2               N
# 3               N
# 4               N
#
# [5 rows x 49 columns]

# %%
sql('''SELECT count(*) FROM complaint;''')
# Out:
#     count
# 0  882281

# %%
func_dep_unclear('complaint')
# Out:
# {'CMPLID': [('ODINO', 1.0),
#   ('MFR_NAME', 0.9999943328712735),
#   ('MAKETXT', 0.9999943328712735),
#   ('MODELTXT', 0.9999943328712735),
#   ('YEARTXT', 0.9999943328712735),
#   ('CRASH', 1.0),
#   ('FAILDATE', 0.87584114358124),
#   ('FIRE', 1.0),
#   ('INJURED', 1.0),
#   ('DEATHS', 1.0),
#   ('COMPDESC', 0.9998605886333266),
#   ('CITY', 0.9999648638018953),
#   ('STATE', 0.9999886657425469),
#   ('VIN', 0.7655701528197932),
#   ('DATEA', 1.0),
#   ('LDATE', 1.0),
#   ('MILES', 0.42486577405611137),
#   ('OCCURENCES', 0.7643415193118746),
#   ('CDESCR', 0.99996373037615),
#   ('CMPL_TYPE', 0.9999988665742547),
#   ('POLICE_RPT_YN', 0.9999988665742547),
#   ('PURCH_DT', 0.39853856084399414),
#   ('ORIG_OWNER_YN', 0.9999988665742547),
#   ('ANTI_BRAKES_YN', 0.9999988665742547),
#   ('CRUISE_CONT_YN', 0.9999988665742547),
#   ('NUM_CYLS', 0.2768585065302324),
#   ('DRIVE_TRAIN', 0.441863759958562),
#   ('FUEL_SYS', 0.3602514391673401),
#   ('FUEL_TYPE', 0.46645683178035113),
#   ('TRANS_TYPE', 0.3595475817795011),
#   ('VEH_SPEED', 0.44225139156345883),
#   ('DOT', 0.008186734158391714),
#   ('TIRE_SIZE', 0.014538452035122598),
#   ('LOC_OF_TIRE', 0.011409063552314965),
#   ('TIRE_FAIL_TYPE', 0.01315680605158674),
#   ('ORIG_EQUIP_YN', 0.9999988665742547),
#   ('MANUF_DT', 0.004990473556610649),
#   ('SEAT_TYPE', 0.00505621224983877),
#   ('RESTRAINT_TYPE', 0.004479298545474741),
#   ('DEALER_NAME', 0.21082172233109406),
#   ('DEALER_TEL', 0.0010688204778296257),
#   ('DEALER_CITY', 0.16994812310363705),
#   ('DEALER_STATE', 0.16928506904262927),
#   ('DEALER_ZIP', 0.11604806178530423),
#   ('PROD_TYPE', 0.9999931994455281),
#   ('REPAIRED_YN', 0.9999988665742547),
#   ('MEDICAL_ATTN', 0.9999988665742547),
#   ('VEHICLES_TOWED_', 0.9999988665742547)],
#  'ODINO': [('CMPLID', 0.6045545580149635),
#   ('MFR_NAME', 0.9681643376656643),
#   ('MAKETXT', 0.96789458233828),
#   ('MODELTXT', 0.9668257618604503),
#   ('YEARTXT', 0.9678832480808268),
#   ('CRASH', 0.9986138203134829),
#   ('FAILDATE', 0.8571747549816895),
#   ('FIRE', 0.9982783262928704),
#   ('INJURED', 0.9982998613820313),
#   ('DEATHS', 0.9998866574254688),
#   ('COMPDESC', 0.645658242668719),
#   ('CITY', 0.9972786447855049),
#   ('STATE', 0.9981015118766017),
#   ('VIN', 0.7757766516563317),
#   ('DATEA', 0.9650814196384145),
#   ('LDATE', 0.9964977144469845),
#   ('MILES', 0.4249099776601786),
#   ('OCCURENCES', 0.7435771596577507),
#   ('CDESCR', 0.9335415814236054),
#   ('CMPL_TYPE', 0.9964331091795018),
#   ('POLICE_RPT_YN', 0.9988722413834141),
#   ('PURCH_DT', 0.4090998219388154),
#   ('ORIG_OWNER_YN', 0.9803463975762824),
#   ('ANTI_BRAKES_YN', 0.9826075819381807),
#   ('CRUISE_CONT_YN', 0.9796833435152746),
#   ('NUM_CYLS', 0.27697638280774495),
#   ('DRIVE_TRAIN', 0.45383273582906125),
#   ('FUEL_SYS', 0.3673659525706663),
#   ('FUEL_TYPE', 0.47829659711588485),
#   ('TRANS_TYPE', 0.36398267672090867),
#   ('VEH_SPEED', 0.45334196248134095),
#   ('DOT', 0.008141397128579217),
#   ('TIRE_SIZE', 0.01453051805490541),
#   ('LOC_OF_TIRE', 0.01139659586911653),
#   ('TIRE_FAIL_TYPE', 0.01314320494264299),
#   ('ORIG_EQUIP_YN', 0.9999954662970187),
#   ('MANUF_DT', 0.0049836730021387745),
#   ('SEAT_TYPE', 0.005058479101329395),
#   ('RESTRAINT_TYPE', 0.004479298545474741),
#   ('DEALER_NAME', 0.21105747488611906),
#   ('DEALER_TEL', 0.0010710873293202506),
#   ('DEALER_CITY', 0.17013400492586828),
#   ('DEALER_STATE', 0.1694698174391152),
#   ('DEALER_ZIP', 0.11617387204303391),
#   ('PROD_TYPE', 0.9702940446411064),
#   ('REPAIRED_YN', 0.9999977331485094),
#   ('MEDICAL_ATTN', 1.0),
#   ('VEHICLES_TOWED_', 1.0)],
#  'MFR_NAME': [('CMPLID', 0.00026635655962533266),
#   ('ODINO', 0.0006585240899673118),
#   ('MAKETXT', 0.07804247197022247),
#   ('MODELTXT', 0.004781950319401185),
#   ('YEARTXT', 0.011806962900498257),
#   ('CRASH', 0.0069626738118230575),
#   ('FAILDATE', 0.0007389977739392208),
#   ('FIRE', 0.01440818972747757),
#   ('INJURED', 0.006749588564122792),
#   ('DEATHS', 0.02850355217641645),
#   ('COMPDESC', 0.0003196278715503992),
#   ('CITY', 0.0006981942158689571),
#   ('STATE', 0.0007480652312881683),
#   ('VIN', 0.001445126014988507),
#   ('DATEA', 0.00067439214032797),
#   ('LDATE', 0.0006834595976769174),
#   ('MILES', 0.0017896893942485118),
#   ('OCCURENCES', 0.002266864337236874),
#   ('CDESCR', 0.0006483232004497459),
#   ('CMPL_TYPE', 0.00313960710707307),
#   ('POLICE_RPT_YN', 0.005688696054295935),
#   ('PURCH_DT', 0.0028188458033540525),
#   ('ORIG_OWNER_YN', 0.005066441793724413),
#   ('ANTI_BRAKES_YN', 0.005741967366221001),
#   ('CRUISE_CONT_YN', 0.006594308357022066),
#   ('NUM_CYLS', 0.004220901395935059),
#   ('DRIVE_TRAIN', 0.003385561887663271),
#   ('FUEL_SYS', 0.013948016267018484),
#   ('FUEL_TYPE', 0.01837406888547348),
#   ('TRANS_TYPE', 0.01569123494235364),
#   ('VEH_SPEED', 0.0019982409132743044),
#   ('DOT', 0.05148842312382973),
#   ('TIRE_SIZE', 0.1939393115079635),
#   ('LOC_OF_TIRE', 0.43287021294923583),
#   ('TIRE_FAIL_TYPE', 0.19523935820536883),
#   ('ORIG_EQUIP_YN', 0.06170064696308185),
#   ('MANUF_DT', 0.2199935167679955),
#   ('SEAT_TYPE', 0.21959001491596733),
#   ('RESTRAINT_TYPE', 0.21937466280392984),
#   ('DEALER_NAME', 0.0019676382447216065),
#   ('DEALER_TEL', 0.02223113855528202),
#   ('DEALER_CITY', 0.0021546545525436486),
#   ('DEALER_STATE', 0.0022623306085624),
#   ('DEALER_ZIP', 0.002306534463138519),
#   ('PROD_TYPE', 0.09150197897256641),
#   ('REPAIRED_YN', 0.7151004900960697),
#   ('MEDICAL_ATTN', 0.4425621914230921),
#   ('VEHICLES_TOWED_', 0.30576712956036434)],
#  'MAKETXT': [('CMPLID', 0.0003128272785386886),
#   ('ODINO', 0.0008364729404404064),
#   ('MFR_NAME', 0.5064435618785958),
#   ('MODELTXT', 0.008184513689593732),
#   ('YEARTXT', 0.015096183053828961),
#   ('CRASH', 0.0078070807774437935),
#   ('FAILDATE', 0.0009169466244123154),
#   ('FIRE', 0.015964392094990683),
#   ('INJURED', 0.007269833929518654),
#   ('DEATHS', 0.03130199620073537),
#   ('COMPDESC', 0.0004023684198595451),
#   ('CITY', 0.0008738762020048148),
#   ('STATE', 0.0009384818356160657),
#   ('VIN', 0.0014360585576395596),
#   ('DATEA', 0.0008500741264638276),
#   ('LDATE', 0.0008591415838127751),
#   ('MILES', 0.001964237948215751),
#   ('OCCURENCES', 0.002700968857817735),
#   ('CDESCR', 0.0008206048900797482),
#   ('CMPL_TYPE', 0.0035827790850028788),
#   ('POLICE_RPT_YN', 0.006275813917640285),
#   ('PURCH_DT', 0.0049383639586705295),
#   ('ORIG_OWNER_YN', 0.005819040753687055),
#   ('ANTI_BRAKES_YN', 0.006545570773771473),
#   ('CRUISE_CONT_YN', 0.00696834097266615),
#   ('NUM_CYLS', 0.004934963662164674),
#   ('DRIVE_TRAIN', 0.003858203101977159),
#   ('FUEL_SYS', 0.015583558886334888),
#   ('FUEL_TYPE', 0.019155003649651583),
#   ('TRANS_TYPE', 0.013598919159084006),
#   ('VEH_SPEED', 0.002529820600356351),
#   ('DOT', 0.06254165363219673),
#   ('TIRE_SIZE', 0.07236851053411858),
#   ('LOC_OF_TIRE', 0.059154958312364836),
#   ('TIRE_FAIL_TYPE', 0.0600072993031659),
#   ('ORIG_EQUIP_YN', 0.21237798602704822),
#   ('MANUF_DT', 0.03195938685853406),
#   ('SEAT_TYPE', 0.031652226740838466),
#   ('RESTRAINT_TYPE', 0.03136093467350353),
#   ('DEALER_NAME', 0.0025128191178270744),
#   ('DEALER_TEL', 0.022193735293717612),
#   ('DEALER_CITY', 0.0024822164492743766),
#   ('DEALER_STATE', 0.0025694907262579962),
#   ('DEALER_ZIP', 0.002775775380946552),
#   ('PROD_TYPE', 0.1878165109330867),
#   ('REPAIRED_YN', 0.9394407192307169),
#   ('MEDICAL_ATTN', 0.591770602396529),
#   ('VEHICLES_TOWED_', 0.5711013333696031)],
#  'MODELTXT': [('CMPLID', 0.001507464784262521),
#   ('ODINO', 0.003201945876347084),
#   ('MFR_NAME', 0.6527685214150674),
#   ('MAKETXT', 0.5561604305228749),
#   ('YEARTXT', 0.04584053062760406),
#   ('CRASH', 0.02927088575457113),
#   ('FAILDATE', 0.003447900656937285),
#   ('FIRE', 0.05491252170522603),
#   ('INJURED', 0.0317281666961359),
#   ('DEATHS', 0.18241570664961984),
#   ('COMPDESC', 0.0019789725664077907),
#   ('CITY', 0.0034138976918787318),
#   ('STATE', 0.003653051879457222),
#   ('VIN', 0.00490889472228645),
#   ('DATEA', 0.003271085238632809),
#   ('LDATE', 0.0033470251939302443),
#   ('MILES', 0.008717226808844398),
#   ('OCCURENCES', 0.010623659716460608),
#   ('CDESCR', 0.003071601176955964),
#   ('CMPL_TYPE', 0.011230045926671473),
#   ('POLICE_RPT_YN', 0.03003481903621996),
#   ('PURCH_DT', 0.006262212731616864),
#   ('ORIG_OWNER_YN', 0.017095557399271884),
#   ('ANTI_BRAKES_YN', 0.02264370786465913),
#   ('CRUISE_CONT_YN', 0.02142640171556293),
#   ('NUM_CYLS', 0.0492918315810472),
#   ('DRIVE_TRAIN', 0.020390444713445678),
#   ('FUEL_SYS', 0.07374903091549583),
#   ('FUEL_TYPE', 0.11329107898208723),
#   ('TRANS_TYPE', 0.07715612801436285),
#   ('VEH_SPEED', 0.007699404721425041),
#   ('DOT', 0.005304462549134284),
#   ('TIRE_SIZE', 0.005404204579972707),
#   ('LOC_OF_TIRE', 0.005352066700216259),
#   ('TIRE_FAIL_TYPE', 0.00559802148080646),
#   ('ORIG_EQUIP_YN', 0.9305478104357366),
#   ('MANUF_DT', 0.0007832016285153399),
#   ('SEAT_TYPE', 0.0032733521029700455),
#   ('RESTRAINT_TYPE', 0.0055617516514106695),
#   ('DEALER_NAME', 0.010993158603430218),
#   ('DEALER_TEL', 0.14176742878645684),
#   ('DEALER_CITY', 0.014767487724929614),
#   ('DEALER_STATE', 0.015083715299974158),
#   ('DEALER_ZIP', 0.016094736794381802),
#   ('PROD_TYPE', 0.900874556261306),
#   ('REPAIRED_YN', 0.9479278593093318),
#   ('MEDICAL_ATTN', 0.9437908318938745),
#   ('VEHICLES_TOWED_', 0.9440141180310924)],
#  'YEARTXT': [('CMPLID', 2.2668643372368736e-06),
#   ('ODINO', 4.533728674473747e-06),
#   ('MFR_NAME', 4.533728674473747e-06),
#   ('MAKETXT', 4.533728674473747e-06),
#   ('MODELTXT', 4.533728674473747e-06),
#   ('CRASH', 5.2137879756448097e-05),
#   ('FAILDATE', 3.400296505855311e-06),
#   ('FIRE', 9.067457348947495e-05),
#   ('INJURED', 5.440474409368497e-05),
#   ('DEATHS', 0.0008342060761031695),
#   ('COMPDESC', 5.667160843092184e-06),
#   ('CITY', 4.533728674473747e-06),
#   ('STATE', 4.533728674473747e-06),
#   ('VIN', 4.533728674473747e-06),
#   ('DATEA', 4.533728674473747e-06),
#   ('LDATE', 4.533728674473747e-06),
#   ('MILES', 1.9268346866513427e-05),
#   ('OCCURENCES', 1.0200889517565932e-05),
#   ('CDESCR', 4.533728674473747e-06),
#   ('CMPL_TYPE', 6.800593011710622e-06),
#   ('POLICE_RPT_YN', 4.647071891335591e-05),
#   ('PURCH_DT', 1.0200889517565932e-05),
#   ('ORIG_OWNER_YN', 2.833580421546092e-05),
#   ('ANTI_BRAKES_YN', 3.400296505855311e-05),
#   ('CRUISE_CONT_YN', 6.233876927401402e-05),
#   ('NUM_CYLS', 1.473461819203968e-05),
#   ('DRIVE_TRAIN', 2.15352112037503e-05),
#   ('FUEL_SYS', 0.0006041193458736268),
#   ('FUEL_TYPE', 0.0005191119332272441),
#   ('TRANS_TYPE', 9.747516650118557e-05),
#   ('VEH_SPEED', 1.7001482529276554e-05),
#   ('DOT', 0.16162516038065186),
#   ('TIRE_SIZE', 0.05561638308193808),
#   ('LOC_OF_TIRE', 0.16164896245619284),
#   ('TIRE_FAIL_TYPE', 0.12472740956344727),
#   ('ORIG_EQUIP_YN', 0.07457190266991282),
#   ('MANUF_DT', 0.004135893983288676),
#   ('SEAT_TYPE', 0.1618983175332889),
#   ('RESTRAINT_TYPE', 0.18919023072145225),
#   ('DEALER_NAME', 6.007190493677715e-05),
#   ('DEALER_TEL', 0.031717965806618335),
#   ('DEALER_CITY', 2.946923638407936e-05),
#   ('DEALER_STATE', 2.946923638407936e-05),
#   ('DEALER_ZIP', 1.1334321686184369e-05),
#   ('PROD_TYPE', 0.0004805752394942172),
#   ('REPAIRED_YN', 0.48564168128794166),
#   ('MEDICAL_ATTN', 0.6904347392425952),
#   ('VEHICLES_TOWED_', 0.7062585857486773)],
#  'CRASH': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('REPAIRED_YN', 0.0),
#   ('MEDICAL_ATTN', 0.9228329749818935),
#   ('VEHICLES_TOWED_', 0.0)],
#  'FAILDATE': [('CMPLID', 0.0007570483139175244),
#   ('ODINO', 0.0012552766914529893),
#   ('MFR_NAME', 0.0015399786214732548),
#   ('MAKETXT', 0.0013575105663239028),
#   ('MODELTXT', 0.0012591589904987202),
#   ('YEARTXT', 0.0014649208399224575),
#   ('CRASH', 0.008801171936671938),
#   ('FIRE', 0.052113394190527705),
#   ('INJURED', 0.018851150066387313),
#   ('DEATHS', 0.7502400554909944),
#   ('COMPDESC', 0.0008476352916512453),
#   ('CITY', 0.0012733940869997333),
#   ('STATE', 0.0013484518685505306),
#   ('VIN', 0.001253982591771079),
#   ('DATEA', 0.001246217993679617),
#   ('LDATE', 0.0012785704857273747),
#   ('MILES', 0.06033610356938574),
#   ('OCCURENCES', 0.024274721833273373),
#   ('CDESCR', 0.0010171623499814944),
#   ('CMPL_TYPE', 0.002140440873879633),
#   ('POLICE_RPT_YN', 0.04530901806304336),
#   ('PURCH_DT', 0.02656916056930033),
#   ('ORIG_OWNER_YN', 0.03326095002445848),
#   ('ANTI_BRAKES_YN', 0.020072780166110634),
#   ('CRUISE_CONT_YN', 0.019361025341059972),
#   ('NUM_CYLS', 0.0830268473920009),
#   ('DRIVE_TRAIN', 0.027331385281945498),
#   ('FUEL_SYS', 0.18901361134045433),
#   ('FUEL_TYPE', 0.1910699357350098),
#   ('TRANS_TYPE', 0.19982710828249678),
#   ('VEH_SPEED', 0.01462979690399592),
#   ('DOT', 0.19619068817632884),
#   ('TIRE_SIZE', 0.1514497798736441),
#   ('LOC_OF_TIRE', 0.20971014755324574),
#   ('TIRE_FAIL_TYPE', 0.20788158470270648),
#   ('ORIG_EQUIP_YN', 0.6928855575887299),
#   ('MANUF_DT', 0.1956186961169245),
#   ('SEAT_TYPE', 0.24930830372001894),
#   ('RESTRAINT_TYPE', 0.2548392857605036),
#   ('DEALER_NAME', 0.07092313306709389),
#   ('DEALER_TEL', 0.08305272938563912),
#   ('DEALER_CITY', 0.07642693901425839),
#   ('DEALER_STATE', 0.07955607204511748),
#   ('DEALER_ZIP', 0.09012239594791507),
#   ('PROD_TYPE', 0.04801756869728161),
#   ('REPAIRED_YN', 0.8792333235844491),
#   ('MEDICAL_ATTN', 0.9973315664559009),
#   ('VEHICLES_TOWED_', 0.9983616698027016)],
#  'FIRE': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('REPAIRED_YN', 0.0),
#   ('MEDICAL_ATTN', 0.032269764394790325),
#   ('VEHICLES_TOWED_', 0.0)],
#  'INJURED': [('CMPLID', 1.020083170781191e-05),
#   ('ODINO', 2.3801940651561124e-05),
#   ('MFR_NAME', 2.3801940651561124e-05),
#   ('MAKETXT', 2.3801940651561124e-05),
#   ('MODELTXT', 2.3801940651561124e-05),
#   ('YEARTXT', 2.3801940651561124e-05),
#   ('CRASH', 3.060249512343573e-05),
#   ('FAILDATE', 2.266851490624869e-05),
#   ('FIRE', 9.180748537030719e-05),
#   ('DEATHS', 5.213758428437198e-05),
#   ('COMPDESC', 1.4734534689061649e-05),
#   ('CITY', 2.606879214218599e-05),
#   ('STATE', 2.606879214218599e-05),
#   ('VIN', 2.493536639687356e-05),
#   ('DATEA', 2.606879214218599e-05),
#   ('LDATE', 2.606879214218599e-05),
#   ('MILES', 1.7001386179686518e-05),
#   ('OCCURENCES', 1.9268237670311385e-05),
#   ('CDESCR', 2.1535089160936256e-05),
#   ('CMPL_TYPE', 2.606879214218599e-05),
#   ('POLICE_RPT_YN', 3.853647534062277e-05),
#   ('PURCH_DT', 2.040166341562382e-05),
#   ('ORIG_OWNER_YN', 3.853647534062277e-05),
#   ('ANTI_BRAKES_YN', 2.606879214218599e-05),
#   ('CRUISE_CONT_YN', 2.606879214218599e-05),
#   ('NUM_CYLS', 3.1735920868748165e-05),
#   ('DRIVE_TRAIN', 2.3801940651561124e-05),
#   ('FUEL_SYS', 2.266851490624869e-05),
#   ('FUEL_TYPE', 0.00012127655474843048),
#   ('TRANS_TYPE', 7.25392476999958e-05),
#   ('VEH_SPEED', 2.606879214218599e-05),
#   ('DOT', 7.027239620937094e-05),
#   ('TIRE_SIZE', 0.00014621192114530404),
#   ('LOC_OF_TIRE', 0.00014621192114530404),
#   ('TIRE_FAIL_TYPE', 0.00017001386179686518),
#   ('ORIG_EQUIP_YN', 0.00026068792142185993),
#   ('MANUF_DT', 0.00012921053496561753),
#   ('SEAT_TYPE', 0.00012921053496561753),
#   ('RESTRAINT_TYPE', 0.00012921053496561753),
#   ('DEALER_NAME', 1.9268237670311385e-05),
#   ('DEALER_TEL', 2.9469069378123298e-05),
#   ('DEALER_CITY', 3.513619810468547e-05),
#   ('DEALER_STATE', 3.513619810468547e-05),
#   ('DEALER_ZIP', 2.9469069378123298e-05),
#   ('PROD_TYPE', 5.553786152030929e-05),
#   ('REPAIRED_YN', 0.0006154501797046519),
#   ('MEDICAL_ATTN', 0.9517047289922371),
#   ('VEHICLES_TOWED_', 0.012811111199266447)],
#  'DEATHS': [('CMPLID', 5.667128726562172e-06),
#   ('ODINO', 1.1334257453124344e-05),
#   ('MFR_NAME', 1.1334257453124344e-05),
#   ('MAKETXT', 1.1334257453124344e-05),
#   ('MODELTXT', 1.1334257453124344e-05),
#   ('YEARTXT', 1.1334257453124344e-05),
#   ('CRASH', 1.1334257453124344e-05),
#   ('FAILDATE', 6.800554471874607e-06),
#   ('FIRE', 4.987073279374712e-05),
#   ('INJURED', 4.193675257656008e-05),
#   ('COMPDESC', 5.667128726562172e-06),
#   ('CITY', 1.1334257453124344e-05),
#   ('STATE', 1.1334257453124344e-05),
#   ('VIN', 1.020083170781191e-05),
#   ('DATEA', 1.1334257453124344e-05),
#   ('LDATE', 1.1334257453124344e-05),
#   ('MILES', 7.933980217187041e-06),
#   ('OCCURENCES', 1.020083170781191e-05),
#   ('CDESCR', 1.1334257453124344e-05),
#   ('CMPL_TYPE', 2.9469069378123298e-05),
#   ('POLICE_RPT_YN', 1.5867960434374083e-05),
#   ('PURCH_DT', 3.4002772359373033e-06),
#   ('ORIG_OWNER_YN', 1.7001386179686518e-05),
#   ('ANTI_BRAKES_YN', 2.9469069378123298e-05),
#   ('CRUISE_CONT_YN', 2.266851490624869e-05),
#   ('NUM_CYLS', 2.266851490624869e-05),
#   ('DRIVE_TRAIN', 2.266851490624869e-05),
#   ('FUEL_SYS', 2.493536639687356e-05),
#   ('FUEL_TYPE', 0.0002663550501484221),
#   ('TRANS_TYPE', 0.00012921053496561753),
#   ('VEH_SPEED', 1.3601108943749213e-05),
#   ('DOT', 0.0001348776636921797),
#   ('TIRE_SIZE', 9.067405962499475e-06),
#   ('LOC_OF_TIRE', 0.0001348776636921797),
#   ('TIRE_FAIL_TYPE', 9.067405962499475e-06),
#   ('ORIG_EQUIP_YN', 0.00027655588185623403),
#   ('MANUF_DT', 2.493536639687356e-05),
#   ('SEAT_TYPE', 2.493536639687356e-05),
#   ('RESTRAINT_TYPE', 0.002298587411493617),
#   ('DEALER_NAME', 1.3601108943749213e-05),
#   ('DEALER_TEL', 0.0004273015059827878),
#   ('DEALER_CITY', 2.1535089160936256e-05),
#   ('DEALER_STATE', 1.246768319843678e-05),
#   ('DEALER_ZIP', 7.933980217187041e-06),
#   ('PROD_TYPE', 3.060249512343573e-05),
#   ('REPAIRED_YN', 0.0002856232878187335),
#   ('MEDICAL_ATTN', 0.0007129247938015212),
#   ('VEHICLES_TOWED_', 0.0030115122052951386)],
#  'COMPDESC': [('CMPLID', 1.133583779776412e-06),
#   ('ODINO', 1.133583779776412e-06),
#   ('MFR_NAME', 1.133583779776412e-06),
#   ('MAKETXT', 1.133583779776412e-06),
#   ('MODELTXT', 1.133583779776412e-06),
#   ('YEARTXT', 1.133583779776412e-06),
#   ('CRASH', 0.0014215140598396205),
#   ('FAILDATE', 7.935086458434883e-06),
#   ('FIRE', 0.015112938951979123),
#   ('INJURED', 0.002318178829642762),
#   ('DEATHS', 0.05248719617120742),
#   ('CITY', 1.133583779776412e-06),
#   ('STATE', 1.133583779776412e-06),
#   ('VIN', 1.133583779776412e-06),
#   ('DATEA', 1.133583779776412e-06),
#   ('LDATE', 1.133583779776412e-06),
#   ('MILES', 0.0010995762663831197),
#   ('OCCURENCES', 3.400751339329236e-05),
#   ('CDESCR', 1.133583779776412e-06),
#   ('CMPL_TYPE', 1.2469421577540532e-05),
#   ('POLICE_RPT_YN', 0.0023635221808338187),
#   ('PURCH_DT', 7.481652946524318e-05),
#   ('ORIG_OWNER_YN', 5.66791889888206e-06),
#   ('ANTI_BRAKES_YN', 0.00028112877738455013),
#   ('CRUISE_CONT_YN', 0.0003899528202430857),
#   ('NUM_CYLS', 0.0007901078945041591),
#   ('DRIVE_TRAIN', 0.0004160252471779432),
#   ('FUEL_SYS', 0.0024644111372339197),
#   ('FUEL_TYPE', 0.007202791336699321),
#   ('TRANS_TYPE', 0.006893322964820361),
#   ('VEH_SPEED', 0.00036728114464755745),
#   ('DOT', 0.11661289700937927),
#   ('TIRE_SIZE', 0.08225737339569555),
#   ('LOC_OF_TIRE', 0.1329512400272967),
#   ('TIRE_FAIL_TYPE', 0.0835916015044924),
#   ('ORIG_EQUIP_YN', 0.04538642737468798),
#   ('MANUF_DT', 0.13870417770966198),
#   ('SEAT_TYPE', 0.189586219248706),
#   ('RESTRAINT_TYPE', 0.24777760899974835),
#   ('DEALER_NAME', 0.00011335837797764119),
#   ('DEALER_TEL', 0.092587722380798),
#   ('DEALER_CITY', 0.0009238707805177758),
#   ('DEALER_STATE', 0.0009238707805177758),
#   ('DEALER_ZIP', 0.0008501878348323089),
#   ('PROD_TYPE', 0.0014294491462980554),
#   ('REPAIRED_YN', 0.18764665740150857),
#   ('MEDICAL_ATTN', 0.8598164954577298),
#   ('VEHICLES_TOWED_', 0.7630333795079793)],
#  'CITY': [('CMPLID', 0.02786511759705299),
#   ('ODINO', 0.04361575517143667),
#   ('MFR_NAME', 0.049106262397279686),
#   ('MAKETXT', 0.04654576367242845),
#   ('MODELTXT', 0.044651742703315386),
#   ('YEARTXT', 0.045918957211674695),
#   ('CRASH', 0.13782601303485406),
#   ('FAILDATE', 0.0425491640691414),
#   ('FIRE', 0.21933918957211676),
#   ('INJURED', 0.1688546330405214),
#   ('DEATHS', 0.6272292434117314),
#   ('COMPDESC', 0.03032813828279966),
#   ('STATE', 0.32202436950977614),
#   ('VIN', 0.044495324454519695),
#   ('DATEA', 0.04409294417682063),
#   ('LDATE', 0.04485123264380844),
#   ('MILES', 0.03352337772740153),
#   ('OCCURENCES', 0.061981297818078776),
#   ('CDESCR', 0.04056786625106262),
#   ('CMPL_TYPE', 0.07519410597903088),
#   ('POLICE_RPT_YN', 0.16172740153017853),
#   ('PURCH_DT', 0.03992405780674412),
#   ('ORIG_OWNER_YN', 0.08086936809294418),
#   ('ANTI_BRAKES_YN', 0.07709946160385378),
#   ('CRUISE_CONT_YN', 0.07776367242844999),
#   ('NUM_CYLS', 0.049085860017001985),
#   ('DRIVE_TRAIN', 0.05236157551714367),
#   ('FUEL_SYS', 0.06798299801643524),
#   ('FUEL_TYPE', 0.2154638707849249),
#   ('TRANS_TYPE', 0.14068688013601588),
#   ('VEH_SPEED', 0.04262964012468121),
#   ('DOT', 0.1565021252479456),
#   ('TIRE_SIZE', 0.1499178237461037),
#   ('LOC_OF_TIRE', 0.19280362708982715),
#   ('TIRE_FAIL_TYPE', 0.18259223576083877),
#   ('ORIG_EQUIP_YN', 0.5872802493624256),
#   ('MANUF_DT', 0.17938792859166902),
#   ('SEAT_TYPE', 0.2219461603853783),
#   ('RESTRAINT_TYPE', 0.24523774440351373),
#   ('DEALER_NAME', 0.03964862567299518),
#   ('DEALER_TEL', 0.1393006517427033),
#   ('DEALER_CITY', 0.048100878435817514),
#   ('DEALER_STATE', 0.16166279399263248),
#   ('DEALER_ZIP', 0.054659110229526776),
#   ('PROD_TYPE', 0.14930461887220176),
#   ('REPAIRED_YN', 0.6700901105128931),
#   ('MEDICAL_ATTN', 0.996946443751771),
#   ('VEHICLES_TOWED_', 0.9876191555681496)],
#  'STATE': [('CMPLID', 6.800631551983461e-06),
#   ('ODINO', 1.1334385919972435e-05),
#   ('MFR_NAME', 1.1334385919972435e-05),
#   ('MAKETXT', 1.1334385919972435e-05),
#   ('MODELTXT', 9.067508735977947e-06),
#   ('YEARTXT', 9.067508735977947e-06),
#   ('CRASH', 6.233912255984839e-05),
#   ('FAILDATE', 1.5868140287961408e-05),
#   ('FIRE', 5.893880678385666e-05),
#   ('INJURED', 0.00014961389414363613),
#   ('DEATHS', 0.001522208029052298),
#   ('COMPDESC', 1.1334385919972435e-05),
#   ('CITY', 1.1334385919972435e-05),
#   ('VIN', 1.926845606395314e-05),
#   ('DATEA', 9.067508735977947e-06),
#   ('LDATE', 1.1334385919972435e-05),
#   ('MILES', 0.0),
#   ('OCCURENCES', 4.760442086388422e-05),
#   ('CDESCR', 1.1334385919972435e-05),
#   ('CMPL_TYPE', 4.6470982271886985e-05),
#   ('POLICE_RPT_YN', 0.0001042763504637464),
#   ('PURCH_DT', 1.1334385919972434e-06),
#   ('ORIG_OWNER_YN', 2.7202526207933843e-05),
#   ('ANTI_BRAKES_YN', 2.60690876159366e-05),
#   ('CRUISE_CONT_YN', 3.513659635191455e-05),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 1.5868140287961408e-05),
#   ('FUEL_SYS', 6.00722453758539e-05),
#   ('FUEL_TYPE', 0.0004477082438389112),
#   ('TRANS_TYPE', 8.047414003180428e-05),
#   ('VEH_SPEED', 1.5868140287961408e-05),
#   ('DOT', 0.0006369924887024509),
#   ('TIRE_SIZE', 8.274101721579877e-05),
#   ('LOC_OF_TIRE', 0.00038196880550307104),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.003067084829944541),
#   ('MANUF_DT', 0.002484497393657958),
#   ('SEAT_TYPE', 0.0025253011829698586),
#   ('RESTRAINT_TYPE', 0.0025253011829698586),
#   ('DEALER_NAME', 1.5868140287961408e-05),
#   ('DEALER_TEL', 0.026504328035263543),
#   ('DEALER_CITY', 2.8335964799931088e-05),
#   ('DEALER_STATE', 2.8335964799931088e-05),
#   ('DEALER_ZIP', 5.553849100786493e-05),
#   ('PROD_TYPE', 8.954164876778223e-05),
#   ('REPAIRED_YN', 0.005432571171442788),
#   ('MEDICAL_ATTN', 0.6482543345525354),
#   ('VEHICLES_TOWED_', 0.6689475229266291)],
#  'VIN': [('CMPLID', 0.13335149411945849),
#   ('ODINO', 0.21720398905615237),
#   ('MFR_NAME', 0.8472983856640334),
#   ('MAKETXT', 0.8267934763297841),
#   ('MODELTXT', 0.6725388186803425),
#   ('YEARTXT', 0.7596691381127785),
#   ('CRASH', 0.6817075481754332),
#   ('FAILDATE', 0.20921521715957409),
#   ('FIRE', 0.8323527495824993),
#   ('INJURED', 0.7467680709691937),
#   ('DEATHS', 0.9718379505158058),
#   ('COMPDESC', 0.15099015764351956),
#   ('CITY', 0.23486486006324692),
#   ('STATE', 0.2489325603155239),
#   ('DATEA', 0.21904869064680035),
#   ('LDATE', 0.22336286435077163),
#   ('MILES', 0.18827948265447525),
#   ('OCCURENCES', 0.36151117480546247),
#   ('CDESCR', 0.2002078620411934),
#   ('CMPL_TYPE', 0.33492437611777665),
#   ('POLICE_RPT_YN', 0.7092122561618363),
#   ('PURCH_DT', 0.22839211900842107),
#   ('ORIG_OWNER_YN', 0.39630437872345464),
#   ('ANTI_BRAKES_YN', 0.4012003884829032),
#   ('CRUISE_CONT_YN', 0.397719735642122),
#   ('NUM_CYLS', 0.5836111736210634),
#   ('DRIVE_TRAIN', 0.5526228517961412),
#   ('FUEL_SYS', 0.46419265435681206),
#   ('FUEL_TYPE', 0.7831083962051854),
#   ('TRANS_TYPE', 0.6460423304236595),
#   ('VEH_SPEED', 0.23904134737241062),
#   ('DOT', 0.03248510618137888),
#   ('TIRE_SIZE', 0.04885646267366252),
#   ('LOC_OF_TIRE', 0.04137106039250986),
#   ('TIRE_FAIL_TYPE', 0.0454898082457865),
#   ('ORIG_EQUIP_YN', 0.9831149104002085),
#   ('MANUF_DT', 0.009752046049436818),
#   ('SEAT_TYPE', 0.010042223827740995),
#   ('RESTRAINT_TYPE', 0.007803709537965913),
#   ('DEALER_NAME', 0.20987551965510298),
#   ('DEALER_TEL', 0.013219374400397959),
#   ('DEALER_CITY', 0.21418821286020537),
#   ('DEALER_STATE', 0.22256635595930405),
#   ('DEALER_ZIP', 0.20958830287453661),
#   ('PROD_TYPE', 0.8588670038256091),
#   ('REPAIRED_YN', 0.9906476886451658),
#   ('MEDICAL_ATTN', 0.999868235600668),
#   ('VEHICLES_TOWED_', 0.9948893179045611)],
#  'DATEA': [('CMPLID', 4.420360406718494e-05),
#   ('ODINO', 7.59395249359331e-05),
#   ('MFR_NAME', 9.180748537030719e-05),
#   ('MAKETXT', 8.614035664374503e-05),
#   ('MODELTXT', 7.59395249359331e-05),
#   ('YEARTXT', 7.933980217187041e-05),
#   ('CRASH', 0.010097689964988478),
#   ('FAILDATE', 9.634118835155693e-05),
#   ('FIRE', 0.05137138848054078),
#   ('INJURED', 0.018135945350744264),
#   ('DEATHS', 0.6214097322735047),
#   ('COMPDESC', 4.647045555780981e-05),
#   ('CITY', 7.59395249359331e-05),
#   ('STATE', 7.820637642655798e-05),
#   ('VIN', 9.407433686093206e-05),
#   ('LDATE', 0.3963929859081177),
#   ('MILES', 0.020631748841922246),
#   ('OCCURENCES', 0.03561223691771669),
#   ('CDESCR', 6.0071564501559024e-05),
#   ('CMPL_TYPE', 0.11926585747624623),
#   ('POLICE_RPT_YN', 0.06852012000711791),
#   ('PURCH_DT', 0.02275352183714712),
#   ('ORIG_OWNER_YN', 0.08504093367079196),
#   ('ANTI_BRAKES_YN', 0.07918905654774386),
#   ('CRUISE_CONT_YN', 0.07310936084988796),
#   ('NUM_CYLS', 0.07536941178604095),
#   ('DRIVE_TRAIN', 0.03921653078781023),
#   ('FUEL_SYS', 0.15779779911388775),
#   ('FUEL_TYPE', 0.15026845188777724),
#   ('TRANS_TYPE', 0.1573376282612909),
#   ('VEH_SPEED', 0.007230122829348019),
#   ('DOT', 0.16323144213691557),
#   ('TIRE_SIZE', 0.11349672043260593),
#   ('LOC_OF_TIRE', 0.17925128162116152),
#   ('TIRE_FAIL_TYPE', 0.1654767585383795),
#   ('ORIG_EQUIP_YN', 0.7430093133593493),
#   ('MANUF_DT', 0.16983931423208706),
#   ('SEAT_TYPE', 0.22462004735452765),
#   ('RESTRAINT_TYPE', 0.2510685371213933),
#   ('DEALER_NAME', 0.028799214762643646),
#   ('DEALER_TEL', 0.08477344519489823),
#   ('DEALER_CITY', 0.023738468809823627),
#   ('DEALER_STATE', 0.024664477643743885),
#   ('DEALER_ZIP', 0.0306999697375326),
#   ('PROD_TYPE', 0.029505339001973295),
#   ('REPAIRED_YN', 0.9064345712987132),
#   ('MEDICAL_ATTN', 0.9974203230036689),
#   ('VEHICLES_TOWED_', 0.9972933793201939)],
#  'LDATE': [('CMPLID', 4.080332683124764e-05),
#   ('ODINO', 7.933980217187041e-05),
#   ('MFR_NAME', 8.954063387968232e-05),
#   ('MAKETXT', 8.954063387968232e-05),
#   ('MODELTXT', 7.933980217187041e-05),
#   ('YEARTXT', 9.067405962499475e-05),
#   ('CRASH', 0.012200194722543046),
#   ('FAILDATE', 0.00011334257453124345),
#   ('FIRE', 0.05648880572062642),
#   ('INJURED', 0.021740239220837804),
#   ('DEATHS', 0.6801302532866513),
#   ('COMPDESC', 4.647045555780981e-05),
#   ('CITY', 7.933980217187041e-05),
#   ('STATE', 8.387350515312015e-05),
#   ('VIN', 0.0001348776636921797),
#   ('DATEA', 0.26927928857132816),
#   ('MILES', 0.03443460756833707),
#   ('OCCURENCES', 0.02923331682309831),
#   ('CDESCR', 5.1004158539059554e-05),
#   ('CMPL_TYPE', 0.06943706143507568),
#   ('POLICE_RPT_YN', 0.06816989145181637),
#   ('PURCH_DT', 0.023877880176497057),
#   ('ORIG_OWNER_YN', 0.08119408669120155),
#   ('ANTI_BRAKES_YN', 0.07814630486205643),
#   ('CRUISE_CONT_YN', 0.07272852979946298),
#   ('NUM_CYLS', 0.06377219956000413),
#   ('DRIVE_TRAIN', 0.038677020133041515),
#   ('FUEL_SYS', 0.1653509482806498),
#   ('FUEL_TYPE', 0.16222949377805937),
#   ('TRANS_TYPE', 0.1651854681218342),
#   ('VEH_SPEED', 0.00918641566575728),
#   ('DOT', 0.15623140473386596),
#   ('TIRE_SIZE', 0.11169344007181385),
#   ('LOC_OF_TIRE', 0.177344859517546),
#   ('TIRE_FAIL_TYPE', 0.16380608898978896),
#   ('ORIG_EQUIP_YN', 0.7456071251676053),
#   ('MANUF_DT', 0.16710322448290285),
#   ('SEAT_TYPE', 0.22842042387856024),
#   ('RESTRAINT_TYPE', 0.25196621031168076),
#   ('DEALER_NAME', 0.022884999223603365),
#   ('DEALER_TEL', 0.07158943692542398),
#   ('DEALER_CITY', 0.022493967341470574),
#   ('DEALER_STATE', 0.02258464140109557),
#   ('DEALER_ZIP', 0.024556802197939206),
#   ('PROD_TYPE', 0.0320396789684919),
#   ('REPAIRED_YN', 0.8990355680333136),
#   ('MEDICAL_ATTN', 0.9974815279939158),
#   ('VEHICLES_TOWED_', 0.9975574675188517)],
#  'MILES': [('CMPLID', 0.07639035243336685),
#   ('ODINO', 0.1232516386510907),
#   ('MFR_NAME', 0.13448543554639042),
#   ('MAKETXT', 0.13039847832872262),
#   ('MODELTXT', 0.12626883748476062),
#   ('YEARTXT', 0.1312761603943967),
#   ('CRASH', 0.23371419577378746),
#   ('FAILDATE', 0.12494297734299761),
#   ('FIRE', 0.272991135144364),
#   ('INJURED', 0.24869348087640156),
#   ('DEATHS', 0.5077564152156456),
#   ('COMPDESC', 0.07806835249205685),
#   ('CITY', 0.12594871028755425),
#   ('STATE', 0.12906461500702945),
#   ('VIN', 0.12661297422175743),
#   ('DATEA', 0.12455082152641983),
#   ('LDATE', 0.12454281834648967),
#   ('OCCURENCES', 0.16955003454706002),
#   ('CDESCR', 0.12339569588983355),
#   ('CMPL_TYPE', 0.17123603778568017),
#   ('POLICE_RPT_YN', 0.2342344024692478),
#   ('PURCH_DT', 0.09490437533846782),
#   ('ORIG_OWNER_YN', 0.1777372876156126),
#   ('ANTI_BRAKES_YN', 0.1656044668414917),
#   ('CRUISE_CONT_YN', 0.1639237990561583),
#   ('NUM_CYLS', 0.12698912367847492),
#   ('DRIVE_TRAIN', 0.11363448410168307),
#   ('FUEL_SYS', 0.16600195811135623),
#   ('FUEL_TYPE', 0.186620817338089),
#   ('TRANS_TYPE', 0.1521031022993136),
#   ('VEH_SPEED', 0.12434807430152248),
#   ('DOT', 0.05741748054560345),
#   ('TIRE_SIZE', 0.04909684114488157),
#   ('LOC_OF_TIRE', 0.06185124222691149),
#   ('TIRE_FAIL_TYPE', 0.06217670487740462),
#   ('ORIG_EQUIP_YN', 0.40378443701630784),
#   ('MANUF_DT', 0.13002499659864852),
#   ('SEAT_TYPE', 0.16678360201786843),
#   ('RESTRAINT_TYPE', 0.18562041984681912),
#   ('DEALER_NAME', 0.09519248981595353),
#   ('DEALER_TEL', 0.22336341639744858),
#   ('DEALER_CITY', 0.09062800952911958),
#   ('DEALER_STATE', 0.09168976473318732),
#   ('DEALER_ZIP', 0.08188053386545588),
#   ('PROD_TYPE', 0.24630319780392743),
#   ('REPAIRED_YN', 0.4967733846248243),
#   ('MEDICAL_ATTN', 0.9889262667033034),
#   ('VEHICLES_TOWED_', 0.9613366377574023)],
#  'OCCURENCES': [('CMPLID', 0.0001230789306665243),
#   ('ODINO', 0.00023281195318848575),
#   ('MFR_NAME', 0.00021946604504392286),
#   ('MAKETXT', 0.00021946604504392286),
#   ('MODELTXT', 0.00021353453031300603),
#   ('YEARTXT', 0.00021946604504392286),
#   ('CRASH', 0.0014977074695565007),
#   ('FAILDATE', 0.0002431921039675902),
#   ('FIRE', 0.004918708590612785),
#   ('INJURED', 0.002169451512832832),
#   ('DEATHS', 0.01086505210835691),
#   ('COMPDESC', 0.00013494196012835797),
#   ('CITY', 0.00023577771055394416),
#   ('STATE', 0.00023874346791940258),
#   ('VIN', 0.0002580208907948823),
#   ('DATEA', 0.0002239146810921105),
#   ('LDATE', 0.00023577771055394416),
#   ('MILES', 0.00021798316636119366),
#   ('CDESCR', 0.00023281195318848575),
#   ('CMPL_TYPE', 0.0004374492114051165),
#   ('POLICE_RPT_YN', 0.0016845501835803809),
#   ('PURCH_DT', 0.0002253975597748397),
#   ('ORIG_OWNER_YN', 0.0003084387660076754),
#   ('ANTI_BRAKES_YN', 0.0003514422478068224),
#   ('CRUISE_CONT_YN', 0.000455243755597867),
#   ('NUM_CYLS', 0.0003988943656541571),
#   ('DRIVE_TRAIN', 0.0002802640710358204),
#   ('FUEL_SYS', 0.00043448345403965813),
#   ('FUEL_TYPE', 0.0011477481004324075),
#   ('TRANS_TYPE', 0.0007310591905854998),
#   ('VEH_SPEED', 0.00026691816289125755),
#   ('DOT', 0.0028678873723982892),
#   ('TIRE_SIZE', 0.004896465410371847),
#   ('LOC_OF_TIRE', 0.015183194832464367),
#   ('TIRE_FAIL_TYPE', 0.013067126952209785),
#   ('ORIG_EQUIP_YN', 0.006303717280281866),
#   ('MANUF_DT', 0.008987727696021732),
#   ('SEAT_TYPE', 0.009036662692551796),
#   ('RESTRAINT_TYPE', 0.008952138607636231),
#   ('DEALER_NAME', 0.0002817469497185496),
#   ('DEALER_TEL', 0.01024817457634156),
#   ('DEALER_CITY', 0.00028322982840127886),
#   ('DEALER_STATE', 0.00028322982840127886),
#   ('DEALER_ZIP', 0.00037071967068230216),
#   ('PROD_TYPE', 0.0016845501835803809),
#   ('REPAIRED_YN', 0.016268662028222147),
#   ('MEDICAL_ATTN', 0.21643948965247256),
#   ('VEHICLES_TOWED_', 0.21643948965247256)],
#  'CDESCR': [('CMPLID', 0.6323282882723584),
#   ('ODINO', 0.96939072756104),
#   ('MFR_NAME', 0.9515340907158863),
#   ('MAKETXT', 0.9502566735694798),
#   ('MODELTXT', 0.9489645213539488),
#   ('YEARTXT', 0.9498860299076565),
#   ('CRASH', 0.9911623589258814),
#   ('FAILDATE', 0.8555475835053369),
#   ('FIRE', 0.99116009199217),
#   ('INJURED', 0.9894020848989344),
#   ('DEATHS', 0.993046180840103),
#   ('COMPDESC', 0.6802558008000009),
#   ('CITY', 0.9719659642572561),
#   ('STATE', 0.9729044748137997),
#   ('VIN', 0.7529064923848029),
#   ('DATEA', 0.9490109934950337),
#   ('LDATE', 0.9724669566074884),
#   ('MILES', 0.4242033711571223),
#   ('OCCURENCES', 0.7472788294461088),
#   ('CMPL_TYPE', 0.985765923225756),
#   ('POLICE_RPT_YN', 0.9900050892661822),
#   ('PURCH_DT', 0.39234161784258187),
#   ('ORIG_OWNER_YN', 0.9649384697517368),
#   ('ANTI_BRAKES_YN', 0.9659733249910173),
#   ('CRUISE_CONT_YN', 0.9640010926620489),
#   ('NUM_CYLS', 0.2770431023441228),
#   ('DRIVE_TRAIN', 0.4390393188317584),
#   ('FUEL_SYS', 0.3585699728761381),
#   ('FUEL_TYPE', 0.470151850554662),
#   ('TRANS_TYPE', 0.3616269329860391),
#   ('VEH_SPEED', 0.44556015365276697),
#   ('DOT', 0.008119023087586384),
#   ('TIRE_SIZE', 0.014521977355599156),
#   ('LOC_OF_TIRE', 0.011365272162394063),
#   ('TIRE_FAIL_TYPE', 0.01313121352361975),
#   ('ORIG_EQUIP_YN', 0.9999852649308755),
#   ('MANUF_DT', 0.004971385629227123),
#   ('SEAT_TYPE', 0.00505979604397398),
#   ('RESTRAINT_TYPE', 0.004480594480696493),
#   ('DEALER_NAME', 0.21089057624321478),
#   ('DEALER_TEL', 0.0010688592449523888),
#   ('DEALER_CITY', 0.1699916916879475),
#   ('DEALER_STATE', 0.16933428091162472),
#   ('DEALER_ZIP', 0.11614521523968857),
#   ('PROD_TYPE', 0.9689532093547286),
#   ('REPAIRED_YN', 0.9999965995994328),
#   ('MEDICAL_ATTN', 0.9999988665331443),
#   ('VEHICLES_TOWED_', 0.9999988665331443)],
#  'CMPL_TYPE': [('CMPLID', 2.2668540599356213e-06),
#   ('ODINO', 2.2668540599356213e-06),
#   ('MFR_NAME', 2.2668540599356213e-06),
#   ('MAKETXT', 2.2668540599356213e-06),
#   ('MODELTXT', 2.2668540599356213e-06),
#   ('YEARTXT', 2.2668540599356213e-06),
#   ('CRASH', 1.2467697329645917e-05),
#   ('FAILDATE', 2.2668540599356213e-06),
#   ('FIRE', 1.2467697329645917e-05),
#   ('INJURED', 1.2467697329645917e-05),
#   ('DEATHS', 1.2467697329645917e-05),
#   ('COMPDESC', 2.2668540599356213e-06),
#   ('CITY', 2.2668540599356213e-06),
#   ('STATE', 2.2668540599356213e-06),
#   ('VIN', 1.1334270299678107e-05),
#   ('DATEA', 2.2668540599356213e-06),
#   ('LDATE', 2.2668540599356213e-06),
#   ('MILES', 1.1334270299678107e-06),
#   ('OCCURENCES', 1.2467697329645917e-05),
#   ('CDESCR', 2.2668540599356213e-06),
#   ('POLICE_RPT_YN', 1.2467697329645917e-05),
#   ('PURCH_DT', 1.1334270299678107e-06),
#   ('ORIG_OWNER_YN', 1.2467697329645917e-05),
#   ('ANTI_BRAKES_YN', 1.2467697329645917e-05),
#   ('CRUISE_CONT_YN', 1.2467697329645917e-05),
#   ('NUM_CYLS', 0.00023008568708346558),
#   ('DRIVE_TRAIN', 1.1334270299678107e-06),
#   ('FUEL_SYS', 1.1334270299678107e-06),
#   ('FUEL_TYPE', 1.1334270299678107e-06),
#   ('TRANS_TYPE', 1.1334270299678107e-06),
#   ('VEH_SPEED', 1.2467697329645917e-05),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.08725801332910187),
#   ('MANUF_DT', 0.0024153330008614047),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.005973160447930362),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.005973160447930362),
#   ('DEALER_STATE', 0.005973160447930362),
#   ('DEALER_ZIP', 1.1334270299678107e-05),
#   ('PROD_TYPE', 6.34719136781974e-05),
#   ('REPAIRED_YN', 0.02298703359477717),
#   ('MEDICAL_ATTN', 0.08725801332910187),
#   ('VEHICLES_TOWED_', 0.1538525184748606)],
#  'POLICE_RPT_YN': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('REPAIRED_YN', 0.0),
#   ('MEDICAL_ATTN', 0.9403375345695244),
#   ('VEHICLES_TOWED_', 0.0)],
#  'PURCH_DT': [('CMPLID', 0.0025083683376798446),
#   ('ODINO', 0.004974077349888944),
#   ('MFR_NAME', 0.00657806798758898),
#   ('MAKETXT', 0.005787448488864494),
#   ('MODELTXT', 0.005346635459000122),
#   ('YEARTXT', 0.011674435403827396),
#   ('CRASH', 0.10440727711213431),
#   ('FAILDATE', 0.005602591411824597),
#   ('FIRE', 0.22253379329566042),
#   ('INJURED', 0.12388268116704539),
#   ('DEATHS', 0.6354618440773214),
#   ('COMPDESC', 0.0026932254147197425),
#   ('CITY', 0.0052072816624623534),
#   ('STATE', 0.005682222152703321),
#   ('VIN', 0.006393210910549082),
#   ('DATEA', 0.0049854531700144755),
#   ('LDATE', 0.0050508641357362855),
#   ('MILES', 0.03171863046501509),
#   ('OCCURENCES', 0.014757282657846614),
#   ('CDESCR', 0.004362627018141589),
#   ('CMPL_TYPE', 0.020587390472181853),
#   ('POLICE_RPT_YN', 0.08912386277348183),
#   ('ORIG_OWNER_YN', 0.015533682381414185),
#   ('ANTI_BRAKES_YN', 0.014137300461005111),
#   ('CRUISE_CONT_YN', 0.01712629719898869),
#   ('NUM_CYLS', 0.04157293464875733),
#   ('DRIVE_TRAIN', 0.01274376249562742),
#   ('FUEL_SYS', 0.06243050084892058),
#   ('FUEL_TYPE', 0.18440773214493933),
#   ('TRANS_TYPE', 0.07088557915722236),
#   ('VEH_SPEED', 0.015445519775441311),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.7383447612926345),
#   ('MANUF_DT', 0.13969507114153512),
#   ('SEAT_TYPE', 0.15967669919203237),
#   ('RESTRAINT_TYPE', 0.1743628829740944),
#   ('DEALER_NAME', 0.03039619137542197),
#   ('DEALER_TEL', 0.1242495513660938),
#   ('DEALER_CITY', 0.03448295475551941),
#   ('DEALER_STATE', 0.0358423652605205),
#   ('DEALER_ZIP', 0.05440770370538901),
#   ('PROD_TYPE', 0.4959516300128262),
#   ('REPAIRED_YN', 1.0),
#   ('MEDICAL_ATTN', 0.9994596485440372),
#   ('VEHICLES_TOWED_', 0.9988908575377606)],
#  'ORIG_OWNER_YN': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('REPAIRED_YN', 0.0),
#   ('MEDICAL_ATTN', 0.0),
#   ('VEHICLES_TOWED_', 0.0)],
#  'ANTI_BRAKES_YN': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('REPAIRED_YN', 0.0),
#   ('MEDICAL_ATTN', 0.0),
#   ('VEHICLES_TOWED_', 0.0)],
#  'CRUISE_CONT_YN': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('REPAIRED_YN', 0.0),
#   ('MEDICAL_ATTN', 0.0),
#   ('VEHICLES_TOWED_', 0.0)],
#  'NUM_CYLS': [('CMPLID', 7.368985577257674e-05),
#   ('ODINO', 9.82531410301023e-05),
#   ('MFR_NAME', 0.00012281642628762788),
#   ('MAKETXT', 0.00011462866453511936),
#   ('MODELTXT', 0.00010644090278261084),
#   ('YEARTXT', 0.00011462866453511936),
#   ('CRASH', 0.000327510470100341),
#   ('FAILDATE', 0.00010644090278261084),
#   ('FIRE', 0.0005199228712842914),
#   ('INJURED', 0.00042576361113044335),
#   ('DEATHS', 0.0011503805262274478),
#   ('COMPDESC', 8.187761752508525e-05),
#   ('CITY', 0.00010644090278261084),
#   ('STATE', 0.00010644090278261084),
#   ('VIN', 9.006537927759379e-05),
#   ('DATEA', 9.82531410301023e-05),
#   ('LDATE', 9.82531410301023e-05),
#   ('MILES', 8.597149840133952e-05),
#   ('OCCURENCES', 0.00010644090278261084),
#   ('CDESCR', 9.82531410301023e-05),
#   ('CMPL_TYPE', 0.00020469404381271314),
#   ('POLICE_RPT_YN', 0.000327510470100341),
#   ('PURCH_DT', 6.55020940200682e-05),
#   ('ORIG_OWNER_YN', 0.0001310041880401364),
#   ('ANTI_BRAKES_YN', 0.0002087879246889674),
#   ('CRUISE_CONT_YN', 0.00021697568644147593),
#   ('DRIVE_TRAIN', 0.00012691030716388216),
#   ('FUEL_SYS', 0.0002701961378327813),
#   ('FUEL_TYPE', 0.0002783838995852899),
#   ('TRANS_TYPE', 0.00028247778046154413),
#   ('VEH_SPEED', 8.187761752508525e-05),
#   ('DOT', 0.0017358054915318074),
#   ('TIRE_SIZE', 0.0023785447891037266),
#   ('LOC_OF_TIRE', 0.0011585682879799563),
#   ('TIRE_FAIL_TYPE', 0.0018013075855518757),
#   ('ORIG_EQUIP_YN', 0.0011872254541137363),
#   ('MANUF_DT', 0.011348237788976817),
#   ('SEAT_TYPE', 0.0005158289904080371),
#   ('RESTRAINT_TYPE', 0.011348237788976817),
#   ('DEALER_NAME', 6.959597489632247e-05),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 5.731433226755968e-05),
#   ('DEALER_STATE', 8.187761752508525e-05),
#   ('DEALER_ZIP', 4.912657051505115e-05),
#   ('PROD_TYPE', 0.0004544207772642232),
#   ('REPAIRED_YN', 0.011888630064642379),
#   ('MEDICAL_ATTN', 0.028890517343726333),
#   ('VEHICLES_TOWED_', 0.028890517343726333)],
#  'DRIVE_TRAIN': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 2.0520818370236605e-05),
#   ('INJURED', 2.0520818370236605e-05),
#   ('DEATHS', 2.0520818370236605e-05),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 2.0520818370236605e-05),
#   ('POLICE_RPT_YN', 2.0520818370236605e-05),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 2.0520818370236605e-05),
#   ('CRUISE_CONT_YN', 2.0520818370236605e-05),
#   ('NUM_CYLS', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 2.0520818370236605e-05),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.20236861546038457),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 2.0520818370236605e-05),
#   ('REPAIRED_YN', 2.0520818370236605e-05),
#   ('MEDICAL_ATTN', 0.28494695368451295),
#   ('VEHICLES_TOWED_', 0.03605507787650571)],
#  'FUEL_SYS': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 2.8315866638560546e-05),
#   ('INJURED', 2.8315866638560546e-05),
#   ('DEATHS', 2.8315866638560546e-05),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 2.8315866638560546e-05),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 2.8315866638560546e-05),
#   ('POLICE_RPT_YN', 2.8315866638560546e-05),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 2.8315866638560546e-05),
#   ('CRUISE_CONT_YN', 2.8315866638560546e-05),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 2.8315866638560546e-05),
#   ('FUEL_TYPE', 2.8315866638560546e-05),
#   ('TRANS_TYPE', 2.8315866638560546e-05),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.40884650597936717),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.05223333532593136),
#   ('REPAIRED_YN', 0.40884650597936717),
#   ('MEDICAL_ATTN', 0.4469974169637211),
#   ('VEHICLES_TOWED_', 0.40884650597936717)],
#  'FUEL_TYPE': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
# ...
#   ('PROD_TYPE', 0.9627526686350216),
#   ('REPAIRED_YN', 1.0),
#   ('MEDICAL_ATTN', 1.0),
#   ('VEHICLES_TOWED_', 1.0)],
#  'SEAT_TYPE': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.15691548980049316),
#   ('FUEL_TYPE', 0.5400134498991258),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.45998655010087425),
#   ('TIRE_SIZE', 0.41425689307330194),
#   ('LOC_OF_TIRE', 0.41425689307330194),
#   ('TIRE_FAIL_TYPE', 0.41425689307330194),
#   ('ORIG_EQUIP_YN', 0.11118583277292086),
#   ('MANUF_DT', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('REPAIRED_YN', 1.0),
#   ('MEDICAL_ATTN', 1.0),
#   ('VEHICLES_TOWED_', 1.0)],
#  'RESTRAINT_TYPE': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 1.0),
#   ('TIRE_SIZE', 0.5498481781376519),
#   ('LOC_OF_TIRE', 0.5498481781376519),
#   ('TIRE_FAIL_TYPE', 0.5498481781376519),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('REPAIRED_YN', 1.0),
#   ('MEDICAL_ATTN', 1.0),
#   ('VEHICLES_TOWED_', 1.0)],
#  'DEALER_NAME': [('CMPLID', 0.23525838154018194),
#   ('ODINO', 0.3994752801015032),
#   ('MFR_NAME', 0.6614105073009182),
#   ('MAKETXT', 0.5920302789187329),
#   ('MODELTXT', 0.42102320380206876),
#   ('YEARTXT', 0.42596933399281733),
#   ('CRASH', 0.7495430205802026),
#   ('FAILDATE', 0.3964162061030946),
#   ('FIRE', 0.8597933377776822),
#   ('INJURED', 0.7814885701382766),
#   ('DEATHS', 0.9661620180211178),
#   ('COMPDESC', 0.24031741252876282),
#   ('CITY', 0.4268671641470076),
#   ('STATE', 0.6743242080815466),
#   ('VIN', 0.3838573364013677),
#   ('DATEA', 0.40595901163415843),
#   ('LDATE', 0.40590524934947636),
#   ('MILES', 0.34736349755919227),
#   ('OCCURENCES', 0.46561364271736094),
#   ('CDESCR', 0.3996419431840175),
#   ('CMPL_TYPE', 0.5290208812713705),
#   ('POLICE_RPT_YN', 0.7291456097718328),
#   ('PURCH_DT', 0.3512290058278317),
#   ('ORIG_OWNER_YN', 0.5142846390400206),
#   ('ANTI_BRAKES_YN', 0.5364508290144298),
#   ('CRUISE_CONT_YN', 0.5601599965592138),
#   ('NUM_CYLS', 0.4476624158620245),
#   ('DRIVE_TRAIN', 0.41980279993978625),
#   ('FUEL_SYS', 0.7129846669964087),
#   ('FUEL_TYPE', 0.7429840218489925),
#   ('TRANS_TYPE', 0.6591955011720179),
#   ('VEH_SPEED', 0.31833186383088535),
#   ('DOT', 0.04651512870690953),
#   ('TIRE_SIZE', 0.07543386163738414),
#   ('LOC_OF_TIRE', 0.06681576740285156),
#   ('TIRE_FAIL_TYPE', 0.07634244424851079),
#   ('ORIG_EQUIP_YN', 0.9523397346293628),
#   ('MANUF_DT', 0.003150469882368121),
#   ('SEAT_TYPE', 0.0023655405260101935),
#   ('RESTRAINT_TYPE', 0.004123567235113223),
#   ('DEALER_TEL', 0.020263005096664587),
#   ('DEALER_CITY', 0.5649609685813208),
#   ('DEALER_STATE', 0.7268553364443775),
#   ('DEALER_ZIP', 0.45030214403991314),
#   ('PROD_TYPE', 0.7878432721876949),
#   ('REPAIRED_YN', 0.9463291112019097),
#   ('MEDICAL_ATTN', 0.9999623664007226),
#   ('VEHICLES_TOWED_', 0.9999516139437862)],
#  'DEALER_TEL': [('CMPLID', 0.4337221633085896),
#   ('ODINO', 0.9607635206786851),
#   ('MFR_NAME', 0.9893955461293743),
#   ('MAKETXT', 0.9872746553552492),
#   ('MODELTXT', 0.9692470837751855),
#   ('YEARTXT', 0.9724284199363733),
#   ('CRASH', 0.9936373276776246),
#   ('FAILDATE', 0.9088016967126193),
#   ('FIRE', 1.0),
#   ('INJURED', 0.9968186638388123),
#   ('DEATHS', 1.0),
#   ('COMPDESC', 0.43796394485683987),
#   ('CITY', 0.9798515376458112),
#   ('STATE', 1.0),
#   ('VIN', 0.9151643690349947),
#   ('DATEA', 0.9671261930010604),
#   ('LDATE', 0.9671261930010604),
#   ('MILES', 0.7423117709437964),
#   ('OCCURENCES', 0.9703075291622482),
#   ('CDESCR', 0.9607635206786851),
#   ('CMPL_TYPE', 0.9936373276776246),
#   ('POLICE_RPT_YN', 0.9968186638388123),
#   ('PURCH_DT', 0.6489925768822906),
#   ('ORIG_OWNER_YN', 0.9830328738069989),
#   ('ANTI_BRAKES_YN', 0.9915164369034994),
#   ('CRUISE_CONT_YN', 0.9915164369034994),
#   ('NUM_CYLS', 0.7645811240721103),
#   ('DRIVE_TRAIN', 0.5334040296924708),
#   ('FUEL_SYS', 0.4984093319194062),
#   ('FUEL_TYPE', 0.7264050901378579),
#   ('TRANS_TYPE', 0.6468716861081655),
#   ('VEH_SPEED', 0.3605514316012725),
#   ('DOT', 0.021208907741251327),
#   ('TIRE_SIZE', 0.03923647932131495),
#   ('LOC_OF_TIRE', 0.024390243902439025),
#   ('TIRE_FAIL_TYPE', 0.04029692470837752),
#   ('ORIG_EQUIP_YN', 1.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.9809119830328739),
#   ('DEALER_CITY', 0.9395546129374337),
#   ('DEALER_STATE', 0.9374337221633086),
#   ('DEALER_ZIP', 0.9088016967126193),
#   ('PROD_TYPE', 1.0),
#   ('REPAIRED_YN', 1.0),
#   ('MEDICAL_ATTN', 1.0),
#   ('VEHICLES_TOWED_', 1.0)],
#  'DEALER_CITY': [('CMPLID', 0.033633004761841244),
#   ('ODINO', 0.056121700390817784),
#   ('MFR_NAME', 0.07112750263435196),
#   ('MAKETXT', 0.06507849701884728),
#   ('MODELTXT', 0.05780235024209361),
#   ('YEARTXT', 0.05898280668525163),
#   ('CRASH', 0.18753918181696924),
#   ('FAILDATE', 0.05649517813554574),
#   ('FIRE', 0.33204172279948246),
#   ('INJURED', 0.22650758293206708),
#   ('DEATHS', 0.8211441757479558),
#   ('COMPDESC', 0.034166544397166904),
#   ('CITY', 0.05929626122100545),
#   ('STATE', 0.16156914006749276),
#   ('VIN', 0.0545677662029318),
#   ('DATEA', 0.056655240026143444),
#   ('LDATE', 0.056661909271585015),
#   ('MILES', 0.054080911285697135),
#   ('OCCURENCES', 0.07360846193861627),
#   ('CDESCR', 0.056121700390817784),
#   ('CMPL_TYPE', 0.08004428378973202),
#   ('POLICE_RPT_YN', 0.1732736658174494),
#   ('PURCH_DT', 0.05329394032359179),
#   ('ORIG_OWNER_YN', 0.07909058169158742),
#   ('ANTI_BRAKES_YN', 0.08449267049925971),
#   ('CRUISE_CONT_YN', 0.09248909578370303),
#   ('NUM_CYLS', 0.0682197116218271),
#   ('DRIVE_TRAIN', 0.06748609462325432),
#   ('FUEL_SYS', 0.26409545024075975),
#   ('FUEL_TYPE', 0.24923637139694016),
#   ('TRANS_TYPE', 0.17249336410078564),
#   ('VEH_SPEED', 0.055601499246375266),
#   ('DOT', 0.1962492163636606),
#   ('TIRE_SIZE', 0.17748195969108055),
#   ('LOC_OF_TIRE', 0.21448960264635658),
#   ('TIRE_FAIL_TYPE', 0.2260874204692481),
#   ('ORIG_EQUIP_YN', 0.6597150898347361),
#   ('MANUF_DT', 0.025616571741073214),
#   ('SEAT_TYPE', 0.03425324458790732),
#   ('RESTRAINT_TYPE', 0.04158274532819357),
#   ('DEALER_NAME', 0.059649731229408705),
#   ('DEALER_TEL', 0.22629416707793681),
#   ('DEALER_STATE', 0.36894932707313494),
#   ('DEALER_ZIP', 0.102526310173267),
#   ('PROD_TYPE', 0.2293019967720852),
#   ('REPAIRED_YN', 0.6694988728975204),
#   ('MEDICAL_ATTN', 0.996271891798162),
#   ('VEHICLES_TOWED_', 0.9905029944912033)],
#  'DEALER_STATE': [('CMPLID', 6.695367475243879e-06),
#   ('ODINO', 6.695367475243879e-06),
#   ('MFR_NAME', 6.695367475243879e-06),
#   ('MAKETXT', 6.695367475243879e-06),
#   ('MODELTXT', 6.695367475243879e-06),
#   ('YEARTXT', 6.695367475243879e-06),
#   ('CRASH', 0.00045528498831658376),
#   ('FAILDATE', 6.695367475243879e-06),
#   ('FIRE', 0.0005758016028709735),
#   ('INJURED', 0.0005021525606432909),
#   ('DEATHS', 0.058671505185562106),
#   ('COMPDESC', 6.695367475243879e-06),
#   ('CITY', 6.695367475243879e-06),
#   ('STATE', 2.6781469900975515e-05),
#   ('VIN', 2.6781469900975515e-05),
#   ('DATEA', 6.695367475243879e-06),
#   ('LDATE', 6.695367475243879e-06),
#   ('MILES', 2.6781469900975515e-05),
#   ('OCCURENCES', 7.364904222768267e-05),
#   ('CDESCR', 6.695367475243879e-06),
#   ('CMPL_TYPE', 0.00020086102425731636),
#   ('POLICE_RPT_YN', 0.0001874702893068286),
#   ('PURCH_DT', 4.686757232670715e-05),
#   ('ORIG_OWNER_YN', 8.703977717817043e-05),
#   ('ANTI_BRAKES_YN', 0.0001272119820296337),
#   ('CRUISE_CONT_YN', 0.00014060271698012147),
#   ('NUM_CYLS', 5.356293980195103e-05),
#   ('DRIVE_TRAIN', 5.356293980195103e-05),
#   ('FUEL_SYS', 0.0003816359460889011),
#   ('FUEL_TYPE', 0.0006293645426729246),
#   ('TRANS_TYPE', 0.00026111933153451125),
#   ('VEH_SPEED', 4.686757232670715e-05),
#   ('DOT', 0.00014060271698012147),
#   ('TIRE_SIZE', 0.00026781469900975514),
#   ('LOC_OF_TIRE', 0.005135346853512055),
#   ('TIRE_FAIL_TYPE', 0.00016738418688109696),
#   ('ORIG_EQUIP_YN', 0.010284084441974598),
#   ('MANUF_DT', 0.2378529295580388),
#   ('SEAT_TYPE', 0.29079320018479216),
#   ('RESTRAINT_TYPE', 0.4041122947032948),
#   ('DEALER_NAME', 6.695367475243879e-06),
#   ('DEALER_TEL', 0.014729808445536533),
#   ('DEALER_CITY', 6.695367475243879e-06),
#   ('DEALER_ZIP', 7.364904222768267e-05),
#   ('PROD_TYPE', 0.0004753710907423154),
#   ('REPAIRED_YN', 0.004847446052076568),
#   ('MEDICAL_ATTN', 0.8312834349913295),
#   ('VEHICLES_TOWED_', 0.757828558420429)],
#  'DEALER_ZIP': [('CMPLID', 0.05492884838895563),
#   ('ODINO', 0.09503159580806157),
#   ('MFR_NAME', 0.13545664976999033),
#   ('MAKETXT', 0.1197905984158145),
#   ('MODELTXT', 0.09926064832449433),
#   ('YEARTXT', 0.10369480500454159),
#   ('CRASH', 0.41882270210085265),
#   ('FAILDATE', 0.09670172971177982),
#   ('FIRE', 0.6545459872835419),
#   ('INJURED', 0.47874241847109494),
#   ('DEATHS', 0.9584712903005265),
#   ('COMPDESC', 0.056432945588795455),
#   ('CITY', 0.1132174983152158),
#   ('STATE', 0.44486116401496284),
#   ('VIN', 0.09956342113744909),
#   ('DATEA', 0.09643802435856115),
#   ('LDATE', 0.0964575580884292),
#   ('MILES', 0.10522820279918349),
#   ('OCCURENCES', 0.15044878744371845),
#   ('CDESCR', 0.09509019699766572),
#   ('CMPL_TYPE', 0.16481584576166897),
#   ('POLICE_RPT_YN', 0.38872122437418816),
#   ('PURCH_DT', 0.10373387246427769),
#   ('ORIG_OWNER_YN', 0.15737349468194203),
#   ('ANTI_BRAKES_YN', 0.17335208571400665),
#   ('CRUISE_CONT_YN', 0.1957084395479895),
#   ('NUM_CYLS', 0.1391387578501177),
#   ('DRIVE_TRAIN', 0.140437750886343),
#   ('FUEL_SYS', 0.5449324621289812),
#   ('FUEL_TYPE', 0.5573754480549289),
#   ('TRANS_TYPE', 0.3698223407268501),
#   ('VEH_SPEED', 0.12845380761229452),
#   ('DOT', 0.1629796751540723),
#   ('TIRE_SIZE', 0.20585621221444128),
#   ('LOC_OF_TIRE', 0.20321915868225457),
#   ('TIRE_FAIL_TYPE', 0.21733227851192047),
#   ('ORIG_EQUIP_YN', 0.9001435729145302),
#   ('MANUF_DT', 0.003906745973609931),
#   ('SEAT_TYPE', 0.006172658638303691),
#   ('RESTRAINT_TYPE', 0.006592633830466758),
#   ('DEALER_NAME', 0.10608768691337768),
#   ('DEALER_TEL', 0.10469102522781212),
#   ('DEALER_CITY', 0.40364499399337805),
#   ('DEALER_STATE', 0.8072509205270201),
#   ('PROD_TYPE', 0.4941838319317882),
#   ('REPAIRED_YN', 0.909929971578423),
#   ('MEDICAL_ATTN', 0.9998827976207917),
#   ('VEHICLES_TOWED_', 0.9993846875091564)],
#  'PROD_TYPE': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.014651894250658808),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.926068402708906),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.926068402708906),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('REPAIRED_YN', 0.014651894250658808),
#   ('MEDICAL_ATTN', 0.07393159729109405),
#   ('VEHICLES_TOWED_', 0.07393159729109405)],
#  'REPAIRED_YN': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 0.0),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.001933626513125085),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 0.0),
#   ('MEDICAL_ATTN', 0.001933626513125085),
#   ('VEHICLES_TOWED_', 0.001933626513125085)],
#  'MEDICAL_ATTN': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 1.700140544951716e-05),
#   ('FAILDATE', 0.0),
#   ('FIRE', 1.700140544951716e-05),
#   ('INJURED', 0.0),
#   ('DEATHS', 0.0),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 1.700140544951716e-05),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 1.700140544951716e-05),
#   ('FUEL_TYPE', 1.700140544951716e-05),
#   ('TRANS_TYPE', 1.700140544951716e-05),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 1.700140544951716e-05),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 1.700140544951716e-05),
#   ('REPAIRED_YN', 1.700140544951716e-05),
#   ('VEHICLES_TOWED_', 0.0)],
#  'VEHICLES_TOWED_': [('CMPLID', 0.0),
#   ('ODINO', 0.0),
#   ('MFR_NAME', 0.0),
#   ('MAKETXT', 0.0),
#   ('MODELTXT', 0.0),
#   ('YEARTXT', 0.0),
#   ('CRASH', 0.0),
#   ('FAILDATE', 0.0),
#   ('FIRE', 0.0),
#   ('INJURED', 0.0),
#   ('DEATHS', 1.813483247948497e-05),
#   ('COMPDESC', 0.0),
#   ('CITY', 0.0),
#   ('STATE', 0.0),
#   ('VIN', 0.0),
#   ('DATEA', 0.0),
#   ('LDATE', 0.0),
#   ('MILES', 0.0),
#   ('OCCURENCES', 0.0),
#   ('CDESCR', 0.0),
#   ('CMPL_TYPE', 0.0),
#   ('POLICE_RPT_YN', 0.0),
#   ('PURCH_DT', 0.0),
#   ('ORIG_OWNER_YN', 0.0),
#   ('ANTI_BRAKES_YN', 0.0),
#   ('CRUISE_CONT_YN', 0.0),
#   ('NUM_CYLS', 0.0),
#   ('DRIVE_TRAIN', 0.0),
#   ('FUEL_SYS', 0.0),
#   ('FUEL_TYPE', 0.0),
#   ('TRANS_TYPE', 0.0),
#   ('VEH_SPEED', 0.0),
#   ('DOT', 0.0),
#   ('TIRE_SIZE', 0.0),
#   ('LOC_OF_TIRE', 0.0),
#   ('TIRE_FAIL_TYPE', 0.0),
#   ('ORIG_EQUIP_YN', 1.813483247948497e-05),
#   ('MANUF_DT', 0.0),
#   ('SEAT_TYPE', 0.0),
#   ('RESTRAINT_TYPE', 0.0),
#   ('DEALER_NAME', 0.0),
#   ('DEALER_TEL', 0.0),
#   ('DEALER_CITY', 0.0),
#   ('DEALER_STATE', 0.0),
#   ('DEALER_ZIP', 0.0),
#   ('PROD_TYPE', 1.813483247948497e-05),
#   ('REPAIRED_YN', 1.813483247948497e-05),
#   ('MEDICAL_ATTN', 0.0)]}

# %% [markdown]
# **Business-Tabelle**

# %%
sql('select * from business limit 5;')
# Out:
#    is_open             business_id     id_third    id_second     id_first  \
# 0        0  --164t1nclzzmca7eDiJMw  USC00410431  US1TXTV0198  USC00410420
# 1        0  --6COJIAjkQwSUZci_4PJQ  US1ORMT0049  US1ORMT0128  US1ORMT0024
# 2        1  --Q3mAcX9t63f7Xcbn7LVA  US1OHDL0017  US1OHFR0024  US1OHDL0012
# 3        1  --UNNdnHRhsyFUbDgumdtQ  US1ORMT0033  US1ORMT0132  USW00024274
# 4        0  --_nBudPOb1lNRgKfjLtrw  US1OHFR0106  US1OHFR0002  US1OHFR0016
#
#                      name              address      city state postal  \
# 0            Me So Hungry        1104 E 6th St    Austin    TX  78702
# 1                  Medley  7881 SW Capitol Hwy  Portland    OR  97219
# 2               The Royce         8791 Lyra Dr  Columbus    OH  43240
# 3               Le Pigeon    738 E Burnside St  Portland    OR  97214
# 4  Mezcal Cantina & Grill         1993 Hard Rd  Columbus    OH  43235
#
#     latitude   longitude  stars  review_count  distance_first  \
# 0  30.264896  -97.731028    4.0           137        0.373439
# 1  45.467868 -122.714524    4.0            99        0.229855
# 2  40.145557  -82.977284    4.5           107        0.979585
# 3  45.522796 -122.657872    4.5          1236        1.165859
# 4  40.117275  -83.068481    4.0             8        0.558175
#
#    distance_second  distance_third categories
# 0         0.572124        0.632392       None
# 1         0.701664        0.705749       None
# 2         2.240159        2.982919       None
# 3         1.785909        2.274014       None
# 4         0.657653        0.840526       None

# %%
dep = func_dep_unclear('business')
# Out:
# ['latitude', 'longitude', 'stars', 'review_count', 'distance_first', 'distance_second', 'distance_third', 'is_open', 'state', 'postal', 'business_id', 'id_third', 'id_second', 'id_first', 'name', 'address', 'city']

# %%
parse_dep(dep)
# Out:
# Funktionale Abhängigkeiten:
# latitude -> longitude: 0.9285911167112931
# latitude -> stars: 0.8345999369979524
# latitude -> review_count: 0.802035753661994
# latitude -> distance_first: 0.9191014332965821
# latitude -> distance_second: 0.9191014332965821
# latitude -> distance_third: 0.9191014332965821
# latitude -> is_open: 0.9044928335170893
# latitude -> state: 0.9991730981256891
# latitude -> postal: 0.9434359741691605
# latitude -> business_id: 0.8001063159552686
# latitude -> id_third: 0.9597771302567334
# latitude -> id_second: 0.960308710033076
# latitude -> id_first: 0.9625728461174988
# latitude -> name: 0.8008938415498503
# latitude -> address: 0.8777169633013073
# latitude -> city: 0.9784414868483226
# longitude -> latitude: 0.9226649866120649
# longitude -> stars: 0.8319814143959678
# longitude -> review_count: 0.799436919199874
# longitude -> distance_first: 0.9136084422743739
# longitude -> distance_second: 0.9136084422743739
# longitude -> distance_third: 0.9136084422743739
# longitude -> is_open: 0.9069144747204284
# longitude -> state: 0.99870058276894
# longitude -> postal: 0.9393605292171996
# longitude -> business_id: 0.7975468577728776
# longitude -> id_third: 0.9658804536147425
# longitude -> id_second: 0.9674555048039061
# longitude -> id_first: 0.9712946920774925
# longitude -> name: 0.7984918884863758
# longitude -> address: 0.8750984406993227
# longitude -> city: 0.9746810521341943
# stars -> latitude: 0.0
# stars -> longitude: 0.0
# stars -> review_count: 0.0
# stars -> distance_first: 0.0
# stars -> distance_second: 0.0
# stars -> distance_third: 0.0
# stars -> is_open: 0.0
# stars -> state: 0.0
# stars -> postal: 0.0
# stars -> business_id: 0.0
# stars -> id_third: 0.0
# stars -> id_second: 0.0
# stars -> id_first: 0.0
# stars -> name: 0.0
# stars -> address: 0.0
# stars -> city: 0.0
# review_count -> latitude: 0.007481493148527327
# review_count -> longitude: 0.007481493148527327
# review_count -> stars: 0.011084422743739171
# review_count -> distance_first: 0.007481493148527327
# review_count -> distance_second: 0.007481493148527327
# review_count -> distance_third: 0.007481493148527327
# review_count -> is_open: 0.028291856985352023
# review_count -> state: 0.008702157820129154
# review_count -> postal: 0.007481493148527327
# review_count -> business_id: 0.007481493148527327
# review_count -> id_third: 0.007481493148527327
# review_count -> id_second: 0.0075208694282564185
# review_count -> id_first: 0.0075208694282564185
# review_count -> name: 0.007481493148527327
# review_count -> address: 0.007481493148527327
# review_count -> city: 0.00822964246338006
# distance_first -> latitude: 1.0
# distance_first -> longitude: 1.0
# distance_first -> stars: 0.8881516774295165
# distance_first -> review_count: 0.8651756182075917
# distance_first -> distance_second: 1.0
# distance_first -> distance_third: 1.0
# distance_first -> is_open: 0.9426090722948496
# distance_first -> state: 1.0
# distance_first -> postal: 0.9811584501496299
# distance_first -> business_id: 0.8637580721373445
# distance_first -> id_third: 1.0
# distance_first -> id_second: 1.0
# distance_first -> id_first: 1.0
# distance_first -> name: 0.8645652858717908
# distance_first -> address: 0.9344581823909277
# distance_first -> city: 0.9939163647818554
# distance_first -> latitude, longitude: 1
# distance_first -> latitude, distance_second: 1
# distance_first -> latitude, distance_third: 1
# distance_first -> latitude, state: 1
# distance_first -> latitude, id_third: 1
# distance_first -> latitude, id_second: 1
# distance_first -> latitude, id_first: 1
# distance_first -> longitude, distance_second: 1
# distance_first -> longitude, distance_third: 1
# distance_first -> longitude, state: 1
# distance_first -> longitude, id_third: 1
# distance_first -> longitude, id_second: 1
# distance_first -> longitude, id_first: 1
# distance_first -> distance_second, distance_third: 1
# distance_first -> distance_second, state: 1
# distance_first -> distance_second, id_third: 1
# distance_first -> distance_second, id_second: 1
# distance_first -> distance_second, id_first: 1
# distance_first -> distance_third, state: 1
# distance_first -> distance_third, id_third: 1
# distance_first -> distance_third, id_second: 1
# distance_first -> distance_third, id_first: 1
# distance_first -> state, id_third: 1
# distance_first -> state, id_second: 1
# distance_first -> state, id_first: 1
# distance_first -> id_third, id_second: 1
# distance_first -> id_third, id_first: 1
# distance_first -> id_second, id_first: 1
# distance_second -> latitude: 1.0
# distance_second -> longitude: 1.0
# distance_second -> stars: 0.8881516774295165
# distance_second -> review_count: 0.8651756182075917
# distance_second -> distance_first: 1.0
# distance_second -> distance_third: 1.0
# distance_second -> is_open: 0.9426090722948496
# distance_second -> state: 1.0
# distance_second -> postal: 0.9811584501496299
# distance_second -> business_id: 0.8637580721373445
# distance_second -> id_third: 1.0
# distance_second -> id_second: 1.0
# distance_second -> id_first: 1.0
# distance_second -> name: 0.8645652858717908
# distance_second -> address: 0.9344581823909277
# distance_second -> city: 0.9939163647818554
# distance_second -> latitude, longitude: 1
# distance_second -> latitude, distance_first: 1
# distance_second -> latitude, distance_third: 1
# distance_second -> latitude, state: 1
# distance_second -> latitude, id_third: 1
# distance_second -> latitude, id_second: 1
# distance_second -> latitude, id_first: 1
# distance_second -> longitude, distance_first: 1
# distance_second -> longitude, distance_third: 1
# distance_second -> longitude, state: 1
# distance_second -> longitude, id_third: 1
# distance_second -> longitude, id_second: 1
# distance_second -> longitude, id_first: 1
# distance_second -> distance_first, distance_third: 1
# distance_second -> distance_first, state: 1
# distance_second -> distance_first, id_third: 1
# distance_second -> distance_first, id_second: 1
# distance_second -> distance_first, id_first: 1
# distance_second -> distance_third, state: 1
# distance_second -> distance_third, id_third: 1
# distance_second -> distance_third, id_second: 1
# distance_second -> distance_third, id_first: 1
# distance_second -> state, id_third: 1
# distance_second -> state, id_second: 1
# distance_second -> state, id_first: 1
# distance_second -> id_third, id_second: 1
# distance_second -> id_third, id_first: 1
# distance_second -> id_second, id_first: 1
# distance_third -> latitude: 1.0
# distance_third -> longitude: 1.0
# distance_third -> stars: 0.8881516774295165
# distance_third -> review_count: 0.8651756182075917
# distance_third -> distance_first: 1.0
# distance_third -> distance_second: 1.0
# distance_third -> is_open: 0.9426090722948496
# distance_third -> state: 1.0
# distance_third -> postal: 0.9811584501496299
# distance_third -> business_id: 0.8637580721373445
# distance_third -> id_third: 1.0
# distance_third -> id_second: 1.0
# distance_third -> id_first: 1.0
# distance_third -> name: 0.8645652858717908
# distance_third -> address: 0.9344581823909277
# distance_third -> city: 0.9939163647818554
# distance_third -> latitude, longitude: 1
# distance_third -> latitude, distance_first: 1
# distance_third -> latitude, distance_second: 1
# distance_third -> latitude, state: 1
# distance_third -> latitude, id_third: 1
# distance_third -> latitude, id_second: 1
# distance_third -> latitude, id_first: 1
# distance_third -> longitude, distance_first: 1
# distance_third -> longitude, distance_second: 1
# distance_third -> longitude, state: 1
# distance_third -> longitude, id_third: 1
# distance_third -> longitude, id_second: 1
# distance_third -> longitude, id_first: 1
# distance_third -> distance_first, distance_second: 1
# distance_third -> distance_first, state: 1
# distance_third -> distance_first, id_third: 1
# distance_third -> distance_first, id_second: 1
# distance_third -> distance_first, id_first: 1
# distance_third -> distance_second, state: 1
# distance_third -> distance_second, id_third: 1
# distance_third -> distance_second, id_second: 1
# distance_third -> distance_second, id_first: 1
# distance_third -> state, id_third: 1
# distance_third -> state, id_second: 1
# distance_third -> state, id_first: 1
# distance_third -> id_third, id_second: 1
# distance_third -> id_third, id_first: 1
# distance_third -> id_second, id_first: 1
# is_open -> latitude: 0.0
# is_open -> longitude: 0.0
# is_open -> stars: 0.0
# is_open -> review_count: 0.0
# is_open -> distance_first: 0.0
# is_open -> distance_second: 0.0
# is_open -> distance_third: 0.0
# is_open -> state: 0.0
# is_open -> postal: 0.0
# is_open -> business_id: 0.0
# is_open -> id_third: 0.0
# is_open -> id_second: 0.0
# is_open -> id_first: 0.0
# is_open -> name: 0.0
# is_open -> address: 0.0
# is_open -> city: 0.0
# state -> latitude: 0.00011812883918727359
# state -> longitude: 0.00011812883918727359
# state -> stars: 0.00011812883918727359
# state -> review_count: 0.00011812883918727359
# state -> distance_first: 0.00011812883918727359
# state -> distance_second: 0.00011812883918727359
# state -> distance_third: 0.00011812883918727359
# state -> is_open: 0.00011812883918727359
# state -> postal: 0.00011812883918727359
# state -> business_id: 0.00011812883918727359
# state -> id_third: 0.00011812883918727359
# state -> id_second: 0.00011812883918727359
# state -> id_first: 0.00011812883918727359
# state -> name: 0.00011812883918727359
# state -> address: 0.00011812883918727359
# state -> city: 0.00011812883918727359
# postal -> latitude: 0.02937470467790203
# postal -> longitude: 0.029236887698850213
# postal -> stars: 0.03408017010552843
# postal -> review_count: 0.02746495511104111
# postal -> distance_first: 0.029040006300204757
# postal -> distance_second: 0.029040006300204757
# postal -> distance_third: 0.029040006300204757
# postal -> is_open: 0.05396519136871948
# postal -> state: 0.9964167585446527
# postal -> business_id: 0.027307449992124744
# postal -> id_third: 0.11875885966293905
# postal -> id_second: 0.1252559458182391
# postal -> id_first: 0.1411048984091983
# postal -> name: 0.027386202551582927
# postal -> address: 0.03104819656638841
# postal -> city: 0.46800677272011343
# business_id -> latitude: 1.0
# business_id -> longitude: 1.0
# business_id -> stars: 1.0
# business_id -> review_count: 1.0
# business_id -> distance_first: 1.0
# business_id -> distance_second: 1.0
# business_id -> distance_third: 1.0
# business_id -> is_open: 1.0
# business_id -> state: 1.0
# business_id -> postal: 1.0
# business_id -> id_third: 1.0
# business_id -> id_second: 1.0
# business_id -> id_first: 1.0
# business_id -> name: 1.0
# business_id -> address: 1.0
# business_id -> city: 1.0
# business_id -> latitude, longitude: 1
# business_id -> latitude, stars: 1
# business_id -> latitude, review_count: 1
# business_id -> latitude, distance_first: 1
# business_id -> latitude, distance_second: 1
# business_id -> latitude, distance_third: 1
# business_id -> latitude, is_open: 1
# business_id -> latitude, state: 1
# business_id -> latitude, postal: 1
# business_id -> latitude, id_third: 1
# business_id -> latitude, id_second: 1
# business_id -> latitude, id_first: 1
# business_id -> latitude, name: 1
# business_id -> latitude, address: 1
# business_id -> latitude, city: 1
# business_id -> longitude, stars: 1
# business_id -> longitude, review_count: 1
# business_id -> longitude, distance_first: 1
# business_id -> longitude, distance_second: 1
# business_id -> longitude, distance_third: 1
# business_id -> longitude, is_open: 1
# business_id -> longitude, state: 1
# business_id -> longitude, postal: 1
# business_id -> longitude, id_third: 1
# business_id -> longitude, id_second: 1
# business_id -> longitude, id_first: 1
# business_id -> longitude, name: 1
# business_id -> longitude, address: 1
# business_id -> longitude, city: 1
# business_id -> stars, review_count: 1
# business_id -> stars, distance_first: 1
# business_id -> stars, distance_second: 1
# business_id -> stars, distance_third: 1
# business_id -> stars, is_open: 1
# business_id -> stars, state: 1
# business_id -> stars, postal: 1
# business_id -> stars, id_third: 1
# business_id -> stars, id_second: 1
# business_id -> stars, id_first: 1
# business_id -> stars, name: 1
# business_id -> stars, address: 1
# business_id -> stars, city: 1
# business_id -> review_count, distance_first: 1
# business_id -> review_count, distance_second: 1
# business_id -> review_count, distance_third: 1
# business_id -> review_count, is_open: 1
# business_id -> review_count, state: 1
# business_id -> review_count, postal: 1
# business_id -> review_count, id_third: 1
# business_id -> review_count, id_second: 1
# business_id -> review_count, id_first: 1
# business_id -> review_count, name: 1
# business_id -> review_count, address: 1
# business_id -> review_count, city: 1
# business_id -> distance_first, distance_second: 1
# business_id -> distance_first, distance_third: 1
# business_id -> distance_first, is_open: 1
# business_id -> distance_first, state: 1
# business_id -> distance_first, postal: 1
# business_id -> distance_first, id_third: 1
# business_id -> distance_first, id_second: 1
# business_id -> distance_first, id_first: 1
# business_id -> distance_first, name: 1
# business_id -> distance_first, address: 1
# business_id -> distance_first, city: 1
# business_id -> distance_second, distance_third: 1
# business_id -> distance_second, is_open: 1
# business_id -> distance_second, state: 1
# business_id -> distance_second, postal: 1
# business_id -> distance_second, id_third: 1
# business_id -> distance_second, id_second: 1
# business_id -> distance_second, id_first: 1
# business_id -> distance_second, name: 1
# business_id -> distance_second, address: 1
# business_id -> distance_second, city: 1
# business_id -> distance_third, is_open: 1
# business_id -> distance_third, state: 1
# business_id -> distance_third, postal: 1
# business_id -> distance_third, id_third: 1
# business_id -> distance_third, id_second: 1
# business_id -> distance_third, id_first: 1
# business_id -> distance_third, name: 1
# business_id -> distance_third, address: 1
# business_id -> distance_third, city: 1
# business_id -> is_open, state: 1
# business_id -> is_open, postal: 1
# business_id -> is_open, id_third: 1
# business_id -> is_open, id_second: 1
# business_id -> is_open, id_first: 1
# business_id -> is_open, name: 1
# business_id -> is_open, address: 1
# business_id -> is_open, city: 1
# business_id -> state, postal: 1
# business_id -> state, id_third: 1
# business_id -> state, id_second: 1
# business_id -> state, id_first: 1
# business_id -> state, name: 1
# business_id -> state, address: 1
# business_id -> state, city: 1
# business_id -> postal, id_third: 1
# business_id -> postal, id_second: 1
# business_id -> postal, id_first: 1
# business_id -> postal, name: 1
# business_id -> postal, address: 1
# business_id -> postal, city: 1
# business_id -> id_third, id_second: 1
# business_id -> id_third, id_first: 1
# business_id -> id_third, name: 1
# business_id -> id_third, address: 1
# business_id -> id_third, city: 1
# business_id -> id_second, id_first: 1
# business_id -> id_second, name: 1
# business_id -> id_second, address: 1
# business_id -> id_second, city: 1
# business_id -> id_first, name: 1
# business_id -> id_first, address: 1
# business_id -> id_first, city: 1
# business_id -> name, address: 1
# business_id -> name, city: 1
# business_id -> address, city: 1
# id_third -> latitude: 0.0023035123641518347
# id_third -> longitude: 0.0023035123641518347
# id_third -> stars: 0.0027563395810363835
# id_third -> review_count: 0.002086942825641833
# id_third -> distance_first: 0.0023035123641518347
# id_third -> distance_second: 0.0023035123641518347
# id_third -> distance_third: 0.0023035123641518347
# id_third -> is_open: 0.00970625295322098
# id_third -> state: 1.0
# id_third -> postal: 0.027543707670499292
# id_third -> business_id: 0.002008190266183651
# id_third -> id_second: 0.09243581666404158
# id_third -> id_first: 0.05617026303354859
# id_third -> name: 0.0020475665459127423
# id_third -> address: 0.0024610174830682
# id_third -> city: 0.2628957316112774
# id_second -> latitude: 0.0022838242242872895
# id_second -> longitude: 0.0022838242242872895
# id_second -> stars: 0.0026578988817136558
# id_second -> review_count: 0.002205071664829107
# id_second -> distance_first: 0.0022838242242872895
# id_second -> distance_second: 0.0022838242242872895
# id_second -> distance_third: 0.0022838242242872895
# id_second -> is_open: 0.007658686407308237
# id_second -> state: 1.0
# id_second -> postal: 0.03112694912584659
# id_second -> business_id: 0.0021263191053709244
# id_second -> id_third: 0.08442274373917152
# id_second -> id_first: 0.11785320522916995
# id_second -> name: 0.0021263191053709244
# id_second -> address: 0.0025594581823909276
# id_second -> city: 0.2796306504961411
# id_first -> latitude: 0.0019688139864545598
# id_first -> longitude: 0.0019688139864545598
# id_first -> stars: 0.0025791463222554732
# id_first -> review_count: 0.0019294377067254685
# id_first -> distance_first: 0.0019688139864545598
# id_first -> distance_second: 0.0019688139864545598
# id_first -> distance_third: 0.0019688139864545598
# id_first -> is_open: 0.007698062687037328
# id_first -> state: 1.0
# id_first -> postal: 0.039632225547330285
# id_first -> business_id: 0.0018506851472672862
# id_first -> id_third: 0.03969128996692393
# id_first -> id_second: 0.09479839344778705
# id_first -> name: 0.0018506851472672862
# id_first -> address: 0.0022247598046936526
# id_first -> city: 0.29666089147897307
# name -> latitude: 0.666896361631753
# name -> longitude: 0.666896361631753
# name -> stars: 0.7059576311230115
# name -> review_count: 0.6671326193101276
# name -> distance_first: 0.6668176090722948
# name -> distance_second: 0.6668176090722948
# name -> distance_third: 0.6668176090722948
# name -> is_open: 0.7678571428571429
# name -> state: 0.8017994959836194
# name -> postal: 0.6729603087100331
# name -> business_id: 0.6663450937155457
# name -> id_third: 0.6731965663884076
# name -> id_second: 0.6729996849897621
# name -> id_first: 0.673787210584344
# name -> address: 0.6675854465270121
# name -> city: 0.7159985824539298
# address -> latitude: 0.6751260040951331
# address -> longitude: 0.6747716175775713
# address -> stars: 0.6835525279571586
# address -> review_count: 0.6337415340998582
# address -> distance_first: 0.6661875885966294
# address -> distance_second: 0.6661875885966294
# address -> distance_third: 0.6661875885966294
# address -> is_open: 0.733363521814459
# address -> state: 0.9893684044731453
# address -> postal: 0.9270554418018586
# address -> business_id: 0.6316152149944874
# address -> id_third: 0.9412899669239251
# address -> id_second: 0.9444400693022523
# address -> id_first: 0.9575326823121751
# address -> name: 0.6326783745471728
# address -> city: 0.9532209796818396
# city -> latitude: 0.0030516616790045676
# city -> longitude: 0.0030122853992754764
# city -> stars: 0.003327295637108206
# city -> review_count: 0.002972909119546385
# city -> distance_first: 0.0030122853992754764
# city -> distance_second: 0.0030122853992754764
# city -> distance_third: 0.0030122853992754764
# city -> is_open: 0.007087730351236415
# city -> state: 0.6613443061899512
# city -> postal: 0.09408962041266342
# city -> business_id: 0.002972909119546385
# city -> id_third: 0.004626712868168215
# city -> id_second: 0.00559143172153095
# city -> id_first: 0.008347771302567333
# city -> name: 0.003169790518191841
# city -> address: 0.0030516616790045676
