# %%
import pandas as pd
import sqlalchemy
import psycopg2

# %%
df_unemployment = pd.read_csv("../../socio/employment_allpostal.csv", sep = ",", header = 1)
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (7,9,11,13,15,21,23,43,45,47,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_unemployment = df_unemployment[["Geographic Area Name", "Estimate!!Unemployment rate!!Population 16 years and over",
                        "Estimate!!Total!!Population 16 years and over",
                        #"Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!White alone",
                        "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!American Indian and Alaska Native alone",
                        "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Asian alone",
                        "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Black or African American alone",
                        "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Native Hawaiian and Other Pacific Islander alone",
                        "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Some other race alone",
                        "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Hispanic or Latino origin (of any race)",
                        "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!White alone, not Hispanic or Latino",
                        "Estimate!!Total!!Population 20 to 64 years!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level",
                        "Estimate!!Total!!Population 20 to 64 years!!POVERTY STATUS IN THE PAST 12 MONTHS!!At or above the poverty level",
                        "Estimate!!Total!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!Less than high school graduate",                        
                        "Estimate!!Total!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!High school graduate (includes equivalency)",
                        "Estimate!!Total!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!Some college or associate's degree",
                        "Estimate!!Total!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!Bachelor's degree or higher",
                        "Estimate!!Total!!Population 20 to 64 years!!SEX!!Male",
                        "Estimate!!Total!!Population 20 to 64 years!!SEX!!Female",
                       ]]

# %%
df_unemployment.rename(columns={"Geographic Area Name": "postal", 
                                "Estimate!!Unemployment rate!!Population 16 years and over": "unemployment_rate",
                                "Estimate!!Total!!Population 16 years and over": "population",
                                "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!American Indian and Alaska Native alone": "native",
                                "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Asian alone": "asian",
                                "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Native Hawaiian and Other Pacific Islander alone": "pacific",
                                "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Some other race alone": "other",
                                "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Black or African American alone": "black",
                                "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Hispanic or Latino origin (of any race)": "hispanic",
                                "Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!White alone, not Hispanic or Latino": "white",
                                "Estimate!!Total!!Population 20 to 64 years!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level": "below_poverty",
                                "Estimate!!Total!!Population 20 to 64 years!!POVERTY STATUS IN THE PAST 12 MONTHS!!At or above the poverty level":"above_poverty",
                                "Estimate!!Total!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!Less than high school graduate": "no_highschool",                        
                                "Estimate!!Total!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!High school graduate (includes equivalency)":"highschool",
                                "Estimate!!Total!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!Some college or associate's degree":"college",
                                "Estimate!!Total!!EDUCATIONAL ATTAINMENT!!Population 25 to 64 years!!Bachelor's degree or higher":"bachelor",
                                "Estimate!!Total!!Population 20 to 64 years!!SEX!!Male":"male",
                                "Estimate!!Total!!Population 20 to 64 years!!SEX!!Female":"female"
                               }, inplace=True)

# %%
df_income = pd.read_csv("../../socio/income_allpostal.csv", sep=",", header = 1)

# %%
df_income = df_income[["Geographic Area Name", "Estimate!!Households!!Median income (dollars)","Estimate!!Households!!Mean income (dollars)"]]

# %%
df_income.rename(columns={"Geographic Area Name": "postal", "Estimate!!Households!!Median income (dollars)": "median_income", "Estimate!!Households!!Mean income (dollars)": "mean_income"}, inplace=True)

# %%
df_unemployment.head()
# Out:
#         postal unemployment_rate  population  native  asian  black  pacific  \
# 0  ZCTA5 00601              35.0       14003      32      2    164        0
# 1  ZCTA5 00602              11.3       31726      28      0    807        0
# 2  ZCTA5 00603              21.0       39163      68    101   1317       11
# 3  ZCTA5 00606              12.0        5417      17      0     92        0
# 4  ZCTA5 00610              11.1       22489       0      0    461        1
#
#    other  hispanic  white  below_poverty  above_poverty  no_highschool  \
# 0   3131     13942     53           5755           4198           2318
# 1    900     29236   2350          11330          11681           5190
# 2   6247     38196    609          12700          12832           4401
# 3   2720      5363     54           2552           1212           1312
# 4   1633     21384    996           6763           8869           2868
#
#    highschool  college  bachelor   male  female
# ...

# %%
df_socio = df_unemployment.merge(df_income,how="left",on='postal')

# %%
df_socio["postal"] = df_unemployment["postal"].str.split(" ").str[1]

# %%
df_socio.head()
# Out:
#   postal unemployment_rate  population  native  asian  black  pacific  other  \
# 0  00601              35.0       14003      32      2    164        0   3131
# 1  00602              11.3       31726      28      0    807        0    900
# 2  00603              21.0       39163      68    101   1317       11   6247
# 3  00606              12.0        5417      17      0     92        0   2720
# 4  00610              11.1       22489       0      0    461        1   1633
#
#    hispanic  white  below_poverty  above_poverty  no_highschool  highschool  \
# 0     13942     53           5755           4198           2318        2431
# 1     29236   2350          11330          11681           5190        5499
# 2     38196    609          12700          12832           4401        6710
# 3      5363     54           2552           1212           1312        1213
# 4     21384    996           6763           8869           2868        4300
#
# ...

# %%
conn = psycopg2.connect(database="db_sync", user="patrick", password="patrick")
cur = conn.cursor()
def sql(sql: str):
    return pd.read_sql(sql, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-129553154587> in <module>
# ----> 1 conn = psycopg2.connect(database="db_sync", user="patrick", password="patrick")
#       2 cur = conn.cursor()
#       3 def sql(sql: str):
#       4     return pd.read_sql(sql, conn)
#
# ~/.local/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  Peer authentication failed for user "patrick"

# %%
#cur.execute("drop table socio;")
#conn.commit()

# %%
try:
    cur.execute("""
                CREATE TABLE socio (
                postal integer PRIMARY KEY, 
                unemployment_rate decimal, 
                population integer,
                native integer,
                black integer,
                asian integer,
                pacific integer,
                other integer,
                hispanic integer,
                white integer,
                below_poverty integer,
                above_poverty integer,
                no_highschool integer,
                highschool integer,
                college integer, 
                bachelor integer,
                male integer, 
                female integer,
                mean_income integer,
                median_income integer
                );
                """)
except:
    print("I can't create table!")

conn.commit() # <--- makes sure the change is shown in the database

cur.close()

# %%
sql('select * from socio limit 5;')
# Out:
#    postal  unemployment_rate  population  native  black  asian  pacific  \
# 0     601               35.0       14003      32    164      2        0
# 1     602               11.3       31726      28    807      0        0
# 2     603               21.0       39163      68   1317    101       11
# 3     606               12.0        5417      17     92      0        0
# 4     610               11.1       22489       0    461      0        1
#
#    other  hispanic  white  below_poverty  above_poverty  no_highschool  \
# 0   3131     13942     53           5755           4198           2318
# 1    900     29236   2350          11330          11681           5190
# 2   6247     38196    609          12700          12832           4401
# 3   2720      5363     54           2552           1212           1312
# 4   1633     21384    996           6763           8869           2868
#
#    highschool  college  bachelor   male  female  mean_income  median_income
# ...

# %%
conn.close()

# %%
engine = sqlalchemy.create_engine('postgresql://patrick:patrick@127.0.0.1:5432/db_sync')

# %%
import numpy as np

# %%
df = df_socio.iloc[::,::].applymap(np.isreal)

# %%
df2 = df_socio[~df_socio.applymap(np.isreal).all(1)]

# %%
df2
# Out:
#       postal unemployment_rate  population  native  asian  black  pacific  \
# 0      00601              35.0       14003      32      2    164        0
# 1      00602              11.3       31726      28      0    807        0
# 2      00603              21.0       39163      68    101   1317       11
# 3      00606              12.0        5417      17      0     92        0
# 4      00610              11.1       22489       0      0    461        1
# ...      ...               ...         ...     ...    ...    ...      ...
# 33115  99923               0.0          14       0      0      0        0
# 33116  99925              16.3         730     265      6      6        7
# 33117  99926              17.7        1228     902      8      0        0
# 33118  99927                 -           0       0      0      0        0
# 33119  99929               6.6        2102     459     16      1        3
#
#        other  hispanic  white  below_poverty  above_poverty  no_highschool  \
# ...

# %%
df[~df.applymap(np.isreal).all(1)]
# Out:
# Empty DataFrame
# Columns: [postal, unemployment_rate, population, native, asian, black, pacific, other, hispanic, white, below_poverty, above_poverty, no_highschool, highschool, college, bachelor, male, female, median_income, mean_income]
# Index: []

# %%
df_socio[df_socio.eq("-").any(1)]
# Out:
#       postal unemployment_rate  population  native  asian  black  pacific  \
# 42     00694                 -          64       0      0      0        0
# 107    00934              58.1          64       0      0     25        0
# 108    00936                 -         773       0      0     29        0
# 110    00950                 -           0       0      0      0        0
# 111    00951                 -           0       0      0      0        0
# ...      ...               ...         ...     ...    ...    ...      ...
# 33085  99781              31.7         103      97      0      0        0
# 33093  99790              33.3          20       4      0      0        0
# 33110  99903                 -           0       0      0      0        0
# 33115  99923               0.0          14       0      0      0        0
# 33118  99927                 -           0       0      0      0        0
#
#        other  hispanic  white  below_poverty  above_poverty  no_highschool  \
# ...

# %%
df_socio[df_socio.eq("N").any(1)]
# Out:
#       postal unemployment_rate  population  native  asian  black  pacific  \
# 42     00694                 -          64       0      0      0        0
# 107    00934              58.1          64       0      0     25        0
# 133    01003              18.9       11357      40   2066    486        0
# 167    01066                 -          31       0      0      0        0
# 322    01561               0.0         209       0     85      0        0
# ...      ...               ...         ...     ...    ...    ...      ...
# 32760  99034               5.6          34       0      0      0        0
# 32846  99321               0.0         319       0      0      0        0
# 33025  99706               0.0           3       2      0      0        0
# 33038  99732               0.0          12       0      0      0        0
# 33115  99923               0.0          14       0      0      0        0
#
#        other  hispanic  white  below_poverty  above_poverty  no_highschool  \
# ...

# %%
df_socio=df_socio.replace(["-"],0)

# %%
df_socio=df_socio.replace(["N"],0)

# %%
#df_socio[df_socio.duplicated(keep=False)]

# %%
df_socio["median_income"] = df_socio["median_income"].astype(str).str.split("-", expand=True)[0]

# %%
df_socio["median_income"] = df_socio["median_income"].astype(str).str.split("+", expand=True)[0]

# %%
df_socio["mean_income"] = df_socio["mean_income"].astype(str).str.split("-", expand=True)[0]

# %%
df_socio["mean_income"] = pd.to_numeric(df_socio["mean_income"])

# %%
#df_socio=df_socio.replace([","],".")

# %%
#df_socio.loc[df_socio['median_income'] == ","]

# %%
df_socio= df_socio.replace(',','', regex=True)

# %%
#df_socio= df_socio.replace('+','', regex=True)

# %%
#pd.to_numeric(df_socio["mean_income"])

# %%
df_socio["median_income"] = pd.to_numeric(df_socio["median_income"])

# %%
df_socio.head()
# Out:
#   postal unemployment_rate  population  native  asian  black  pacific  other  \
# 0  00601              35.0       14003      32      2    164        0   3131
# 1  00602              11.3       31726      28      0    807        0    900
# 2  00603              21.0       39163      68    101   1317       11   6247
# 3  00606              12.0        5417      17      0     92        0   2720
# 4  00610              11.1       22489       0      0    461        1   1633
#
#    hispanic  white  below_poverty  above_poverty  no_highschool  highschool  \
# 0     13942     53           5755           4198           2318        2431
# 1     29236   2350          11330          11681           5190        5499
# 2     38196    609          12700          12832           4401        6710
# 3      5363     54           2552           1212           1312        1213
# 4     21384    996           6763           8869           2868        4300
#
# ...

# %%
#df_socio.select_dtypes(include=np.number).columns.tolist()

# %%
#df_socio.loc[df_socio['postal'] == "99362"]

# %%
#df_socio.drop(6929, inplace = True)
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy
import pgeocode

df_socio['postal']=df_socio['postal'].astype(int)

data = pd.read_csv('../Karten/US.txt', sep="\t", header = None, names=['country','postal', 'name','state' , 'admincode1', 'adminname2', 'admincode2', 'adminname3', 'admincode3','latitude', 'longitude', 'accuracy'])

edf = pd.merge(df_socio,data[['postal','latitude', 'longitude']],on='postal')#.drop(columns= ['latitude_x', 'longitude_x'])
edf = edf.rename(columns={"latitude_y": "latitude", "longitude_y": "longitude"})


engine = sqlalchemy.create_engine('postgresql://kevin:12345678@127.0.0.1:5432/db_sync')
edf.to_sql('socio', engine, if_exists='replace', index = False)

# %%
socios = ["native", "asian", "pacific", "other", "hispanic", "white", "black", "below_poverty", "above_poverty",
          "no_highschool", "highschool", "college", "bachelor", "male", "female"]

edf = edf[edf.population != 0]

for socio in socios:
    socio_ratio = socio + "_ratio"
    edf[socio_ratio] = edf.apply(lambda row: row[socio]/row.population, axis = 1)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import pandas as pd
import numpy as np
import psycopg2
import sqlalchemy
import pgeocode


conn = psycopg2.connect(database="db_sync", user="kevin", password="12345678")
cur = conn.cursor()
def sql(sql: str):
    return pd.read_sql(sql, conn)



edf = sql("SELECT * FROM socio;")
edf = edf.drop(columns = ['unemployment_rate','native_ratio','asian_ratio','pacific_ratio','other_ratio','hispanic_ratio','white_ratio','black_ratio','below_poverty_ratio','above_poverty_ratio','no_highschool_ratio','highschool_ratio','college_ratio','bachelor_ratio','male_ratio','female_ratio']).astype(int)
# Out:
#        postal unemployment_rate  population  native  asian  black  pacific  \
# 0        1001               3.9       14386       6    456    429        0
# 1        1002               5.8       26656      99   2869   1361       63
# 2        1003              18.9       11357      40   2066    486        0
# 3        1005               2.9        4333       0     33     86       30
# 4        1007               4.2       12187       0    578     83        0
# ...       ...               ...         ...     ...    ...    ...      ...
# 32969   99923               0.0          14       0      0      0        0
# 32970   99925              16.3         730     265      6      6        7
# 32971   99926              17.7        1228     902      8      0        0
# 32972   99927                 0           0       0      0      0        0
# 32973   99929               6.6        2102     459     16      1        3
#
# ...

# %%
conn = psycopg2.connect(database="db_sync", user="kevin", password="12345678")
cur = conn.cursor()
try:
    cur.execute("""
                ALTER TABLE socio
                ADD native_ratio float,
                ADD asian_ratio float,
                ADD pacific_ratio float,
                ADD other_ratio float,
                ADD hispanic_ratio float,
                ADD white_ratio float,
                ADD black_ratio float,
                ADD below_poverty_ratio float,
                ADD above_poverty_ratio float,
                ADD no_highschool_ratio float,
                ADD highschool_ratio float,
                ADD college_ratio float,
                ADD bachelor_ratio float,
                ADD male_ratio float,
                ADD female_ratio float;
                """)
except:
    print("I can't alter table!")

conn.commit() # <--- makes sure the change is shown in the database

cur.close()

# %%
edf['unemployment_rate'] = sql("SELECT * FROM socio;")['unemployment_rate']

# %%
edf
# Out:
#        postal unemployment_rate  population  native  asian  black  pacific  \
# 0        1001               3.9       14386       6    456    429        0
# 1        1002               5.8       26656      99   2869   1361       63
# 2        1003              18.9       11357      40   2066    486        0
# 3        1005               2.9        4333       0     33     86       30
# 4        1007               4.2       12187       0    578     83        0
# ...       ...               ...         ...     ...    ...    ...      ...
# 32968   99922              12.0         253     190      0      4       12
# 32969   99923               0.0          14       0      0      0        0
# 32970   99925              16.3         730     265      6      6        7
# 32971   99926              17.7        1228     902      8      0        0
# 32973   99929               6.6        2102     459     16      1        3
#
#        other  hispanic  white  ...  white_ratio  black_ratio  \
# ...

# %%
engine = sqlalchemy.create_engine('postgresql://kevin:12345678@127.0.0.1:5432/db_sync')
edf.to_sql('socio', engine, if_exists='replace', index = False)
